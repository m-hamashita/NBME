# %%
# ====================================================
# Directory settings
# ====================================================
import os
from pathlib import Path

INPUT_DIR = Path("../input")
OUTPUT_DIR = Path('../output')
os.makedirs(INPUT_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
import os
import gc
import re
import ast
import sys
import copy
import json
import time
import math
import string
import pickle
import random
import joblib
import itertools
import warnings
warnings.filterwarnings("ignore")

import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold, GroupKFold, KFold

import torch
import torch.nn as nn
from torch.nn import Parameter
import torch.nn.functional as F
from torch.optim import Adam, SGD, AdamW
from torch.utils.data import DataLoader, Dataset

# os.system('pip uninstall -y transformers')
# os.system('python -m pip install --no-index --find-links=../input/nbme-pip-wheels transformers')
import tokenizers
import transformers
print(f"tokenizers.__version__: {tokenizers.__version__}")
print(f"transformers.__version__: {transformers.__version__}")
from transformers import AutoTokenizer, AutoModel, AutoConfig
from transformers import get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
# Out:
# tokenizers.__version__: 0.12.1
# transformers.__version__: 4.18.0

# %%
# ====================================================
# Data Loading
# ====================================================
train = pd.read_csv(INPUT_DIR / 'train.csv')
test = pd.read_csv(INPUT_DIR / 'test.csv')
train['annotation'] = train['annotation'].apply(ast.literal_eval)
train['location'] = train['location'].apply(ast.literal_eval)
features = pd.read_csv(INPUT_DIR / 'features.csv')
def preprocess_features(features):
    features.loc[27, 'feature_text'] = "Last-Pap-smear-1-year-ago"
#     features['feature_text'] = features['feature_text'].str.replace("-"," ")
    return features
features = preprocess_features(features)
patient_notes = pd.read_csv(INPUT_DIR / 'patient_notes.csv')

print(f"train.shape: {train.shape}")
print(f"features.shape: {features.shape}")
print(f"patient_notes.shape: {patient_notes.shape}")
# Out:
# train.shape: (14300, 6)
# features.shape: (143, 3)
# patient_notes.shape: (42146, 3)

# %%
train = train.merge(features, on=['feature_num', 'case_num'], how='left')
train = train.merge(patient_notes, on=['pn_num', 'case_num'], how='left')
test = test.merge(features, on=['feature_num', 'case_num'], how='left')
test = test.merge(patient_notes, on=['pn_num', 'case_num'], how='left')
display(train.head())
# Out:
#           id  case_num  pn_num  feature_num                              annotation          location                                       feature_text                                         pn_history
# 0  00016_000         0      16            0          [dad with recent heart attcak]         [696 724]  Family-history-of-MI-OR-Family-history-of-myoc...  HPI: 17yo M presents with palpitations. Patien...
# 1  00016_001         0      16            1             [mom with "thyroid disease]         [668 693]                 Family-history-of-thyroid-disorder  HPI: 17yo M presents with palpitations. Patien...
# 2  00016_002         0      16            2                        [chest pressure]         [203 217]                                     Chest-pressure  HPI: 17yo M presents with palpitations. Patien...
# 3  00016_003         0      16            3        [intermittent episodes, episode]  [70 91, 176 183]                              Intermittent-symptoms  HPI: 17yo M presents with palpitations. Patien...
# 4  00016_004         0      16            4  [felt as if he were going to pass out]         [222 258]                                        Lightheaded  HPI: 17yo M presents with palpitations. Patien...

# %%
# incorrect annotation
train.loc[338, 'annotation'] = ast.literal_eval('[["father heart attack"]]')
train.loc[338, 'location'] = ast.literal_eval('[["764 783"]]')

train.loc[621, 'annotation'] = ast.literal_eval('[["for the last 2-3 months"]]')
train.loc[621, 'location'] = ast.literal_eval('[["77 100"]]')

train.loc[655, 'annotation'] = ast.literal_eval('[["no heat intolerance"], ["no cold intolerance"]]')
train.loc[655, 'location'] = ast.literal_eval('[["285 292;301 312"], ["285 287;296 312"]]')

train.loc[1262, 'annotation'] = ast.literal_eval('[["mother thyroid problem"]]')
train.loc[1262, 'location'] = ast.literal_eval('[["551 557;565 580"]]')

train.loc[1265, 'annotation'] = ast.literal_eval('[[\'felt like he was going to "pass out"\']]')
train.loc[1265, 'location'] = ast.literal_eval('[["131 135;181 212"]]')

train.loc[1396, 'annotation'] = ast.literal_eval('[["stool , with no blood"]]')
train.loc[1396, 'location'] = ast.literal_eval('[["259 280"]]')

train.loc[1591, 'annotation'] = ast.literal_eval('[["diarrhoe non blooody"]]')
train.loc[1591, 'location'] = ast.literal_eval('[["176 184;201 212"]]')

train.loc[1615, 'annotation'] = ast.literal_eval('[["diarrhea for last 2-3 days"]]')
train.loc[1615, 'location'] = ast.literal_eval('[["249 257;271 288"]]')

train.loc[1664, 'annotation'] = ast.literal_eval('[["no vaginal discharge"]]')
train.loc[1664, 'location'] = ast.literal_eval('[["822 824;907 924"]]')

train.loc[1714, 'annotation'] = ast.literal_eval('[["started about 8-10 hours ago"]]')
train.loc[1714, 'location'] = ast.literal_eval('[["101 129"]]')

train.loc[1929, 'annotation'] = ast.literal_eval('[["no blood in the stool"]]')
train.loc[1929, 'location'] = ast.literal_eval('[["531 539;549 561"]]')

train.loc[2134, 'annotation'] = ast.literal_eval('[["last sexually active 9 months ago"]]')
train.loc[2134, 'location'] = ast.literal_eval('[["540 560;581 593"]]')

train.loc[2191, 'annotation'] = ast.literal_eval('[["right lower quadrant pain"]]')
train.loc[2191, 'location'] = ast.literal_eval('[["32 57"]]')

train.loc[2553, 'annotation'] = ast.literal_eval('[["diarrhoea no blood"]]')
train.loc[2553, 'location'] = ast.literal_eval('[["308 317;376 384"]]')

train.loc[3124, 'annotation'] = ast.literal_eval('[["sweating"]]')
train.loc[3124, 'location'] = ast.literal_eval('[["549 557"]]')

train.loc[3858, 'annotation'] = ast.literal_eval('[["previously as regular"], ["previously eveyr 28-29 days"], ["previously lasting 5 days"], ["previously regular flow"]]')
train.loc[3858, 'location'] = ast.literal_eval('[["102 123"], ["102 112;125 141"], ["102 112;143 157"], ["102 112;159 171"]]')

train.loc[4373, 'annotation'] = ast.literal_eval('[["for 2 months"]]')
train.loc[4373, 'location'] = ast.literal_eval('[["33 45"]]')

train.loc[4763, 'annotation'] = ast.literal_eval('[["35 year old"]]')
train.loc[4763, 'location'] = ast.literal_eval('[["5 16"]]')

train.loc[4782, 'annotation'] = ast.literal_eval('[["darker brown stools"]]')
train.loc[4782, 'location'] = ast.literal_eval('[["175 194"]]')

train.loc[4908, 'annotation'] = ast.literal_eval('[["uncle with peptic ulcer"]]')
train.loc[4908, 'location'] = ast.literal_eval('[["700 723"]]')

train.loc[6016, 'annotation'] = ast.literal_eval('[["difficulty falling asleep"]]')
train.loc[6016, 'location'] = ast.literal_eval('[["225 250"]]')

train.loc[6192, 'annotation'] = ast.literal_eval('[["helps to take care of aging mother and in-laws"]]')
train.loc[6192, 'location'] = ast.literal_eval('[["197 218;236 260"]]')

train.loc[6380, 'annotation'] = ast.literal_eval('[["No hair changes"], ["No skin changes"], ["No GI changes"], ["No palpitations"], ["No excessive sweating"]]')
train.loc[6380, 'location'] = ast.literal_eval('[["480 482;507 519"], ["480 482;499 503;512 519"], ["480 482;521 531"], ["480 482;533 545"], ["480 482;564 582"]]')

train.loc[6562, 'annotation'] = ast.literal_eval('[["stressed due to taking care of her mother"], ["stressed due to taking care of husbands parents"]]')
train.loc[6562, 'location'] = ast.literal_eval('[["290 320;327 337"], ["290 320;342 358"]]')

train.loc[6862, 'annotation'] = ast.literal_eval('[["stressor taking care of many sick family members"]]')
train.loc[6862, 'location'] = ast.literal_eval('[["288 296;324 363"]]')

train.loc[7022, 'annotation'] = ast.literal_eval('[["heart started racing and felt numbness for the 1st time in her finger tips"]]')
train.loc[7022, 'location'] = ast.literal_eval('[["108 182"]]')

train.loc[7422, 'annotation'] = ast.literal_eval('[["first started 5 yrs"]]')
train.loc[7422, 'location'] = ast.literal_eval('[["102 121"]]')

train.loc[8876, 'annotation'] = ast.literal_eval('[["No shortness of breath"]]')
train.loc[8876, 'location'] = ast.literal_eval('[["481 483;533 552"]]')

train.loc[9027, 'annotation'] = ast.literal_eval('[["recent URI"], ["nasal stuffines, rhinorrhea, for 3-4 days"]]')
train.loc[9027, 'location'] = ast.literal_eval('[["92 102"], ["123 164"]]')

train.loc[9938, 'annotation'] = ast.literal_eval('[["irregularity with her cycles"], ["heavier bleeding"], ["changes her pad every couple hours"]]')
train.loc[9938, 'location'] = ast.literal_eval('[["89 117"], ["122 138"], ["368 402"]]')

train.loc[9973, 'annotation'] = ast.literal_eval('[["gaining 10-15 lbs"]]')
train.loc[9973, 'location'] = ast.literal_eval('[["344 361"]]')

train.loc[10513, 'annotation'] = ast.literal_eval('[["weight gain"], ["gain of 10-16lbs"]]')
train.loc[10513, 'location'] = ast.literal_eval('[["600 611"], ["607 623"]]')

train.loc[11551, 'annotation'] = ast.literal_eval('[["seeing her son knows are not real"]]')
train.loc[11551, 'location'] = ast.literal_eval('[["386 400;443 461"]]')

train.loc[11677, 'annotation'] = ast.literal_eval('[["saw him once in the kitchen after he died"]]')
train.loc[11677, 'location'] = ast.literal_eval('[["160 201"]]')

train.loc[12124, 'annotation'] = ast.literal_eval('[["tried Ambien but it didnt work"]]')
train.loc[12124, 'location'] = ast.literal_eval('[["325 337;349 366"]]')

train.loc[12279, 'annotation'] = ast.literal_eval('[["heard what she described as a party later than evening these things did not actually happen"]]')
train.loc[12279, 'location'] = ast.literal_eval('[["405 459;488 524"]]')

train.loc[12289, 'annotation'] = ast.literal_eval('[["experienced seeing her son at the kitchen table these things did not actually happen"]]')
train.loc[12289, 'location'] = ast.literal_eval('[["353 400;488 524"]]')

train.loc[13238, 'annotation'] = ast.literal_eval('[["SCRACHY THROAT"], ["RUNNY NOSE"]]')
train.loc[13238, 'location'] = ast.literal_eval('[["293 307"], ["321 331"]]')

train.loc[13297, 'annotation'] = ast.literal_eval('[["without improvement when taking tylenol"], ["without improvement when taking ibuprofen"]]')
train.loc[13297, 'location'] = ast.literal_eval('[["182 221"], ["182 213;225 234"]]')

train.loc[13299, 'annotation'] = ast.literal_eval('[["yesterday"], ["yesterday"]]')
train.loc[13299, 'location'] = ast.literal_eval('[["79 88"], ["409 418"]]')

train.loc[13845, 'annotation'] = ast.literal_eval('[["headache global"], ["headache throughout her head"]]')
train.loc[13845, 'location'] = ast.literal_eval('[["86 94;230 236"], ["86 94;237 256"]]')

train.loc[14083, 'annotation'] = ast.literal_eval('[["headache generalized in her head"]]')
train.loc[14083, 'location'] = ast.literal_eval('[["56 64;156 179"]]')

# %%
train["case_num"].value_counts()
# Out:
# 5    1800
# 8    1800
# 2    1700
# 9    1700
# 3    1600
# 0    1300
# 1    1300
# 6    1200
# 4    1000
# 7     900
# Name: case_num, dtype: int64

# %%
train["feature_num"].value_counts()
# Out:
# 0      100
# 611    100
# 605    100
# 606    100
# 607    100
# 608    100
# 609    100
# 610    100
# 700    100
# 603    100
# 701    100
# 702    100
# 703    100
# 704    100
# 705    100
# 706    100
# 604    100
# 602    100
# 708    100
# 511    100
# 505    100
# 506    100
# 507    100
# 508    100
# 509    100
# 510    100
# 512    100
# 601    100
# 513    100
# 514    100
# 515    100
# 516    100
# 517    100
# 600    100
# 707    100
# 800    100
# 503    100
# 908    100
# 902    100
# 903    100
# 904    100
# 905    100
# 906    100
# 907    100
# 909    100
# 900    100
# 910    100
# 911    100
# 912    100
# 913    100
# 914    100
# 915    100
# 901    100
# 817    100
# 801    100
# 808    100
# 802    100
# 803    100
# 804    100
# 805    100
# 806    100
# 807    100
# 809    100
# 816    100
# 810    100
# 811    100
# 812    100
# 813    100
# 814    100
# 815    100
# 504    100
# 502    100
# 1      100
# 200    100
# 107    100
# 108    100
# 109    100
# 110    100
# 111    100
# 112    100
# 201    100
# 105    100
# 202    100
# 203    100
# 204    100
# 205    100
# 206    100
# 207    100
# 106    100
# 104    100
# 209    100
# 8      100
# 2      100
# 3      100
# 4      100
# 5      100
# 6      100
# 7      100
# 9      100
# 103    100
# 10     100
# 11     100
# 12     100
# 100    100
# 101    100
# 102    100
# 208    100
# 210    100
# 501    100
# 403    100
# 313    100
# 314    100
# 315    100
# 400    100
# 401    100
# 402    100
# 404    100
# 311    100
# 405    100
# 406    100
# 407    100
# 408    100
# 409    100
# 500    100
# 312    100
# 310    100
# 211    100
# 301    100
# 212    100
# 213    100
# 214    100
# 215    100
# 216    100
# 300    100
# 302    100
# 309    100
# 303    100
# 304    100
# 305    100
# 306    100
# 307    100
# 308    100
# 916    100
# Name: feature_num, dtype: int64

# %%
train["pn_num"].value_counts()
# Out:
# 50072    18
# 56535    18
# 56697    18
# 56841    18
# 57026    18
#          ..
# 71449     9
# 71432     9
# 71344     9
# 71235     9
# 74087     9
# Name: pn_num, Length: 1000, dtype: int64

# %%
train["feature_text"].value_counts()
# Out:
# Female                                                                  700
# Male                                                                    300
# 20-year                                                                 200
# Nausea                                                                  200
# 35-year                                                                 200
# 17-year                                                                 200
# Family-history-of-MI-OR-Family-history-of-myocardial-infarction         100
# Worse-with-deep-breath-OR-pleuritic                                     100
# Chest-pain                                                              100
# Duration-x-1-day                                                        100
# No-shortness-of-breath                                                  100
# Recent-heavy-lifting-at-work-OR-recent-rock-climbing                    100
# No-relief-with-asthma-inhaler                                           100
# Sharp-OR-stabbing-OR-7-to-8-out-of-10-on-pain-scale                     100
# Weight-Gain                                                             100
# heavy-periods-OR-irregular-periods                                      100
# Last-menstrual-period-2-months-ago                                      100
# Unprotected-Sex                                                         100
# Fatigue                                                                 100
# Exercise-induced-asthma                                                 100
# 26-year                                                                 100
# Recent-upper-respiratory-symptoms                                       100
# Subjective-fevers                                                       100
# symptoms-for-6-months                                                   100
# Increased-stress                                                        100
# Fatigue-OR-Difficulty-concentrating                                     100
# Episode-of-hand-numbness-OR-Episode-of-finger-numbness                  100
# Feels-hot-OR-Feels-clammy                                               100
# Associated-throat-tightness                                             100
# Episodes-last-15-to-30-minutes                                          100
# Associated-feeling-of-impending-doom                                    100
# Increased-frequency-recently                                            100
# Associated-nausea                                                       100
# No-illicit-drug-use                                                     100
# No-chest-pain                                                           100
# Infertility-HX-OR-Infertility-history                                   100
# Son-died-3-weeks-ago                                                    100
# Increased-appetite                                                      100
# Difficulty-with-sleep                                                   100
# No-known-illness-contacts                                               100
# Photophobia                                                             100
# Family-history-of-migraines                                             100
# Meningococcal-vaccine-status-unknown                                    100
# Shares-an-apartment                                                     100
# viral-symptoms-OR-rhinorrhea-OR-scratchy-throat                         100
# No-rash                                                                 100
# Vomiting                                                                100
# Neck-pain                                                               100
# Global-headache-OR-diffuse-headache                                     100
# Myalgias                                                                100
# 1-day-duration-OR-2-days-duration                                       100
# No-relief-with-Motrin-OR-no-relief-with-tylenol                         100
# No-suicidal-ideations                                                   100
# Episodes-of-heart-racing                                                100
# Early-wakening                                                          100
# FHx-of-depression-OR-Family-history-of-depression                       100
# Visual-hallucination-once                                               100
# loss-of-interest                                                        100
# Diminished-energy-OR-feeling-drained                                    100
# Sleeping-medication-ineffective                                         100
# Unsuccessful-napping                                                    100
# duration-3-weeks                                                        100
# Hallucinations-after-taking-Ambien                                      100
# Difficulty-falling-asleep                                               100
# 67-year                                                                 100
# tossing-and-turning                                                     100
# Auditory-hallucination-once                                             100
# Recent-visit-to-emergency-department-with-negative-workup               100
# 45-year                                                                 100
# Associated-SOB-OR-Associated-shortness-of-breath                        100
# Recurrent-bouts-over-past-6-months                                      100
# No-premenstrual-symptoms                                                100
# Recent-nausea-vomiting-OR-Recent-flulike-symptoms                       100
# Irregular-menses                                                        100
# Vaginal-dryness                                                         100
# Sexually-active                                                         100
# IUD                                                                     100
# Last-Pap-smear-1-year-ago                                               100
# Prior-normal-periods                                                    100
# 8-to-10-hours-of-acute-pain                                             100
# Normal-LMP-2-weeks-ago-OR-Normal-last-menstrual-period-2-weeks-ago      100
# Diminished-appetite                                                     100
# No-urinary-symptoms                                                     100
# Right-sided-LQ-abdominal-pain-OR-Right-lower-quadrant-abdominal-pain    100
# No-bloody-bowel-movements                                               100
# No-caffeine-use                                                         100
# Prior-episodes-of-diarrhea                                              100
# Not-sexually-active                                                     100
# Weight-loss                                                             100
# No-vaginal-discharge                                                    100
# Few-months-duration                                                     100
# heart-pounding-OR-heart-racing                                          100
# Caffeine-use                                                            100
# Shortness-of-breath                                                     100
# Adderall-use                                                            100
# No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance        100
# Lightheaded                                                             100
# Intermittent-symptoms                                                   100
# Chest-pressure                                                          100
# Stress                                                                  100
# LMP-2-months-ago-or-Last-menstrual-period-2-months-ago                  100
# Hot-flashes                                                             100
# Irregular-flow-OR-Irregular-frequency-OR-Irregular-intervals            100
# Onset-5-years-ago                                                       100
# Family-history-of-thyroid-disorder                                      100
# Decreased-appetite                                                      100
# Insomnia                                                                100
# Weight-stable                                                           100
# No-depressed-mood                                                       100
# Heavy-caffeine-use                                                      100
# Stress-due-to-caring-for-elderly-parents                                100
# anxious-OR-nervous                                                      100
# Lack-of-other-thyroid-symptoms                                          100
# Minimal-to-no-change-with-Tums                                          100
# Intermittent                                                            100
# No-blood-in-stool                                                       100
# Awakens-at-night                                                        100
# duration-2-months                                                       100
# 2-to-3-beers-a-week                                                     100
# getting-worse-OR-progressive-OR-symptoms-now-daily                      100
# Post-prandial-bloating-OR-fullness-with-meals                           100
# burning-OR-gnawing-OR-burning-and-gnawing                               100
# NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use                    100
# Darker-bowel-movements                                                  100
# Epigastric-discomfort                                                   100
# FHx-of-PUD-OR-Family-history-of-peptic-ulcer-disease                    100
# 44-year                                                                 100
# Sleep-disturbance-OR-Early-awakenings                                   100
# Heavy-sweating                                                          100
# Onset-3-years-ago                                                       100
# Subjective-fever                                                        100
# Name: feature_text, dtype: int64

# %%
print(train.head())
print(len(train))
# Out:
#           id  case_num  pn_num  feature_num                              annotation          location                                       feature_text                                         pn_history
# 0  00016_000         0      16            0          [dad with recent heart attcak]         [696 724]  Family-history-of-MI-OR-Family-history-of-myoc...  HPI: 17yo M presents with palpitations. Patien...
# 1  00016_001         0      16            1             [mom with "thyroid disease]         [668 693]                 Family-history-of-thyroid-disorder  HPI: 17yo M presents with palpitations. Patien...
# 2  00016_002         0      16            2                        [chest pressure]         [203 217]                                     Chest-pressure  HPI: 17yo M presents with palpitations. Patien...
# 3  00016_003         0      16            3        [intermittent episodes, episode]  [70 91, 176 183]                              Intermittent-symptoms  HPI: 17yo M presents with palpitations. Patien...
# 4  00016_004         0      16            4  [felt as if he were going to pass out]         [222 258]                                        Lightheaded  HPI: 17yo M presents with palpitations. Patien...
# 14300

# %%
heart_pounding = train[train["feature_text"]=="heart-pounding-OR-heart-racing"]

# %%
heart_pounding["annotation"]
# Out:
# 9                  [palpitations, heart beating/pounding]
# 22                                       [HEART POUNDING]
# 35             [palpitations, palpitations, palpitations]
# 48         [heart pounding, heart racing, heart pounding]
# 61                       [pounding heart, pounding heart]
# 74                                          [palpitaions]
# 87         [heart pounding, heart pounding, palpitations]
# 100     [palpitations, Palpitations, palpitations, hea...
# 113                                      [heart pounding]
# 126                      [heart pounding, heart is pound]
# 139                                      [heart pounding]
# 152       [palpitations, palpitations, heart is pounding]
# 165                   [pounding heart beat, palpitations]
# 178                                        [palpitations]
# 191                                      [heart pounding]
# 204                                      [HEART POUNDING]
# 217                                  [heart palpitations]
# 230                                   [heart palpitation]
# 243                                      [heart pounding]
# 256                           [heart racing/palpitations]
# 269                      [heart pounding, heart pounding]
# 282                     [heart pounding, heart is racing]
# 295     [heart feeling like it is going to beat out of...
# 308                       [heart pounding, heart punding]
# 321                                      [heart pounding]
# 334                                      [heart pounding]
# 347          [increased heart rate, increased heart rate]
# 360                                         [PALPITATIPN]
# 373                  [heart pounding, heart beating fast]
# 386                                  [heart palpitations]
# 399                      [heart pounding, heart pounding]
# 412                                      [HEART POUNDING]
# 425     [heart pounding, heart "jumping out of his chest]
# 438                                         [palpitation]
# 451                                      [heart pounding]
# 464                         [heart pounding, tachycardia]
# 477                                      [heart pounding]
# 490                      [Heart pounding, heart pounding]
# 503                                        [palpitations]
# 516                                      [heart pounding]
# 529                                  [HEART PALPITATIONS]
# 542                      [heart pounding, chest pounding]
# 555                                                    []
# 568                   [heart is 'pounding', heart racing]
# 581                      [Heart Pounding, heart pounding]
# 594                          [palpitations, palpitations]
# 607                      [pounding heart, heart pounding]
# 620                                        [palpitations]
# 633                                  [heart palpitations]
# 646                                        [heart racing]
# 659                                         [palpitation]
# 672                                [cardiac palpitations]
# 685                                      [heart pounding]
# 698                                        [heart racing]
# 711                                  [heart palpitations]
# 724                                      [heart pounding]
# 737     [heart pounding, heart feels like its beating ...
# 750                       [heart beating out of my chest]
# 763     [heart pounding, feels like my chest is going ...
# 776     [heart racing, heart pounding, heart has been ...
# 789          [heart racing, heart pounding, heart pounds]
# 802                      [heart pounding, heart pounding]
# 815                       [heart pounding, heart jumping]
# 828                            [palpiations, tachycardia]
# 841                                      [heart pounding]
# 854                                        [palpitations]
# 867                          [racing heart, palpitations]
# 880     [heart pounding, heart is bearting really fast...
# 893                                 [rapid heart beating]
# 906                                      [heart pounding]
# 919        [heart pounding, heart racing, heart pounding]
# 932                        [palpitations, heart pounding]
# 945                                  [chest palpitations]
# 958                                     [RACING OF HEART]
# 971                        [heart pounding, heart racing]
# 984          [heart pounding, palpitations, palpitations]
# 997                                      [heart pounding]
# 1010                       [heart pounding, heart racing]
# 1023                                 [heart palpitations]
# 1036                         [palpitations, palpitations]
# 1049                                       [palpatations]
# 1062                                       [palpitations]
# 1075                     [heart pounding, heart pounding]
# 1088                                     [Heart Pounding]
# 1101    [My heart has been pounding, heart pounding, h...
# 1114                                     [chest pounding]
# 1127                                      [heart punding]
# 1140    [irregular heartbeat, pounding in his chest, h...
# 1153                                       [PALPITATIONS]
# 1166                         [palpitations, palpitations]
# 1179                                       [palpitations]
# 1192                                       [palpitations]
# 1205                       [heart pounding, heart racing]
# 1218                                  [heart is pounding]
# 1231    [heart is pounding and going to jump out of my...
# 1244                                 [heart palpitations]
# 1257                                        [palpitation]
# 1270                                       [palpitations]
# 1283                       [heart pounding, heart racing]
# 1296             [chest palpitations, chest palpitations]
# Name: annotation, dtype: object

# %%
sum(heart_pounding["pn_history"].str.contains("Heart pounding"))
# Out:
# 1

# %%
sum(heart_pounding["annotation"].apply(lambda x: "heart pounding" in " ".join(x)))
# Out:
# 45

# %% [markdown]
# ## feature_text の uni-gram, bi-gram を取ってきて、 annotation rate(sum(annotation)/sum(pn_history)) が大きいやつに対して hard labeling

# %%
train["feature_text_list"] = train["feature_text"].apply(lambda x: x.split("-OR-")).apply(lambda x: [x1.split("-") for x1 in x])

# %%
def ngram(feature_text_lists, n: int):
    return [" ".join(feature_text_list[k:k+n]) for feature_text_list in feature_text_lists for k in range(len(feature_text_list)-n+1)]

# %%
train["feature_text_unigram"] = train["feature_text_list"].apply(ngram, n=1)
train["feature_text_bigram"] = train["feature_text_list"].apply(ngram, n=2)

# %%
train["feature_text_bigram"]
# Out:
# 0        [Family history, history of, of MI, Family his...
# 1        [Family history, history of, of thyroid, thyro...
# 2                                         [Chest pressure]
# 3                                  [Intermittent symptoms]
# 4                                                       []
#                                ...
# 14295           [Family history, history of, of migraines]
# 14296                                                   []
# 14297                                                   []
# 14298          [No known, known illness, illness contacts]
# 14299                                   [Subjective fever]
# Name: feature_text_bigram, Length: 14300, dtype: object

# %%
heart_pounding["annotation"]
# Out:
# 9                  [palpitations, heart beating/pounding]
# 22                                       [HEART POUNDING]
# 35             [palpitations, palpitations, palpitations]
# 48         [heart pounding, heart racing, heart pounding]
# 61                       [pounding heart, pounding heart]
# 74                                          [palpitaions]
# 87         [heart pounding, heart pounding, palpitations]
# 100     [palpitations, Palpitations, palpitations, hea...
# 113                                      [heart pounding]
# 126                      [heart pounding, heart is pound]
# 139                                      [heart pounding]
# 152       [palpitations, palpitations, heart is pounding]
# 165                   [pounding heart beat, palpitations]
# 178                                        [palpitations]
# 191                                      [heart pounding]
# 204                                      [HEART POUNDING]
# 217                                  [heart palpitations]
# 230                                   [heart palpitation]
# 243                                      [heart pounding]
# 256                           [heart racing/palpitations]
# 269                      [heart pounding, heart pounding]
# 282                     [heart pounding, heart is racing]
# 295     [heart feeling like it is going to beat out of...
# 308                       [heart pounding, heart punding]
# 321                                      [heart pounding]
# 334                                      [heart pounding]
# 347          [increased heart rate, increased heart rate]
# 360                                         [PALPITATIPN]
# 373                  [heart pounding, heart beating fast]
# 386                                  [heart palpitations]
# 399                      [heart pounding, heart pounding]
# 412                                      [HEART POUNDING]
# 425     [heart pounding, heart "jumping out of his chest]
# 438                                         [palpitation]
# 451                                      [heart pounding]
# 464                         [heart pounding, tachycardia]
# 477                                      [heart pounding]
# 490                      [Heart pounding, heart pounding]
# 503                                        [palpitations]
# 516                                      [heart pounding]
# 529                                  [HEART PALPITATIONS]
# 542                      [heart pounding, chest pounding]
# 555                                                    []
# 568                   [heart is 'pounding', heart racing]
# 581                      [Heart Pounding, heart pounding]
# 594                          [palpitations, palpitations]
# 607                      [pounding heart, heart pounding]
# 620                                        [palpitations]
# 633                                  [heart palpitations]
# 646                                        [heart racing]
# 659                                         [palpitation]
# 672                                [cardiac palpitations]
# 685                                      [heart pounding]
# 698                                        [heart racing]
# 711                                  [heart palpitations]
# 724                                      [heart pounding]
# 737     [heart pounding, heart feels like its beating ...
# 750                       [heart beating out of my chest]
# 763     [heart pounding, feels like my chest is going ...
# 776     [heart racing, heart pounding, heart has been ...
# 789          [heart racing, heart pounding, heart pounds]
# 802                      [heart pounding, heart pounding]
# 815                       [heart pounding, heart jumping]
# 828                            [palpiations, tachycardia]
# 841                                      [heart pounding]
# 854                                        [palpitations]
# 867                          [racing heart, palpitations]
# 880     [heart pounding, heart is bearting really fast...
# 893                                 [rapid heart beating]
# 906                                      [heart pounding]
# 919        [heart pounding, heart racing, heart pounding]
# 932                        [palpitations, heart pounding]
# 945                                  [chest palpitations]
# 958                                     [RACING OF HEART]
# 971                        [heart pounding, heart racing]
# 984          [heart pounding, palpitations, palpitations]
# 997                                      [heart pounding]
# 1010                       [heart pounding, heart racing]
# 1023                                 [heart palpitations]
# 1036                         [palpitations, palpitations]
# 1049                                       [palpatations]
# 1062                                       [palpitations]
# 1075                     [heart pounding, heart pounding]
# 1088                                     [Heart Pounding]
# 1101    [My heart has been pounding, heart pounding, h...
# 1114                                     [chest pounding]
# 1127                                      [heart punding]
# 1140    [irregular heartbeat, pounding in his chest, h...
# 1153                                       [PALPITATIONS]
# 1166                         [palpitations, palpitations]
# 1179                                       [palpitations]
# 1192                                       [palpitations]
# 1205                       [heart pounding, heart racing]
# 1218                                  [heart is pounding]
# 1231    [heart is pounding and going to jump out of my...
# 1244                                 [heart palpitations]
# 1257                                        [palpitation]
# 1270                                       [palpitations]
# 1283                       [heart pounding, heart racing]
# 1296             [chest palpitations, chest palpitations]
# Name: annotation, dtype: object

# %%
feature_texts = train["feature_text"].unique()

# %%
feature_text_list_unigram = {feature_text: [ngram([feature.lower().split("-")], 1) for feature in feature_text.split("-OR-")] for feature_text in feature_texts}
feature_text_list_bigram = {feature_text: [ngram([feature.lower().split("-")], 2) for feature in feature_text.split("-OR-")] for feature_text in feature_texts}

# %%
feature_text_list_unigram
# Out:
# {'Family-history-of-MI-OR-Family-history-of-myocardial-infarction': [['family',
#    'history',
#    'of',
#    'mi'],
#   ['family', 'history', 'of', 'myocardial', 'infarction']],
#  'Family-history-of-thyroid-disorder': [['family',
#    'history',
#    'of',
#    'thyroid',
#    'disorder']],
#  'Chest-pressure': [['chest', 'pressure']],
#  'Intermittent-symptoms': [['intermittent', 'symptoms']],
#  'Lightheaded': [['lightheaded']],
#  'No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance': [['no',
#    'hair',
#    'changes'],
#   ['no', 'nail', 'changes'],
#   ['no', 'temperature', 'intolerance']],
#  'Adderall-use': [['adderall', 'use']],
#  'Shortness-of-breath': [['shortness', 'of', 'breath']],
#  'Caffeine-use': [['caffeine', 'use']],
#  'heart-pounding-OR-heart-racing': [['heart', 'pounding'],
#   ['heart', 'racing']],
#  'Few-months-duration': [['few', 'months', 'duration']],
#  '17-year': [['17', 'year']],
#  'Male': [['male']],
#  'No-vaginal-discharge': [['no', 'vaginal', 'discharge']],
#  'Weight-loss': [['weight', 'loss']],
#  'Not-sexually-active': [['not', 'sexually', 'active']],
#  'Prior-episodes-of-diarrhea': [['prior', 'episodes', 'of', 'diarrhea']],
#  '20-year': [['20', 'year']],
#  'No-bloody-bowel-movements': [['no', 'bloody', 'bowel', 'movements']],
#  'Recurrent-bouts-over-past-6-months': [['recurrent',
#    'bouts',
#    'over',
#    'past',
#    '6',
#    'months']],
#  'Right-sided-LQ-abdominal-pain-OR-Right-lower-quadrant-abdominal-pain': [['right',
#    'sided',
#    'lq',
#    'abdominal',
#    'pain'],
#   ['right', 'lower', 'quadrant', 'abdominal', 'pain']],
#  'No-urinary-symptoms': [['no', 'urinary', 'symptoms']],
#  'Diminished-appetite': [['diminished', 'appetite']],
#  'Normal-LMP-2-weeks-ago-OR-Normal-last-menstrual-period-2-weeks-ago': [['normal',
#    'lmp',
#    '2',
#    'weeks',
#    'ago'],
#   ['normal', 'last', 'menstrual', 'period', '2', 'weeks', 'ago']],
#  '8-to-10-hours-of-acute-pain': [['8',
#    'to',
#    '10',
#    'hours',
#    'of',
#    'acute',
#    'pain']],
#  'Female': [['female']],
#  'Prior-normal-periods': [['prior', 'normal', 'periods']],
#  'Last-Pap-smear-1-year-ago': [['last', 'pap', 'smear', '1', 'year', 'ago']],
#  'IUD': [['iud']],
#  'Sexually-active': [['sexually', 'active']],
#  'Vaginal-dryness': [['vaginal', 'dryness']],
#  'Irregular-menses': [['irregular', 'menses']],
#  'Recent-nausea-vomiting-OR-Recent-flulike-symptoms': [['recent',
#    'nausea',
#    'vomiting'],
#   ['recent', 'flulike', 'symptoms']],
#  'No-premenstrual-symptoms': [['no', 'premenstrual', 'symptoms']],
#  'Stress': [['stress']],
#  'LMP-2-months-ago-or-Last-menstrual-period-2-months-ago': [['lmp',
#    '2',
#    'months',
#    'ago',
#    'or',
#    'last',
#    'menstrual',
#    'period',
#    '2',
#    'months',
#    'ago']],
#  'Hot-flashes': [['hot', 'flashes']],
#  'Irregular-flow-OR-Irregular-frequency-OR-Irregular-intervals': [['irregular',
#    'flow'],
#   ['irregular', 'frequency'],
#   ['irregular', 'intervals']],
#  'Onset-3-years-ago': [['onset', '3', 'years', 'ago']],
#  'Heavy-sweating': [['heavy', 'sweating']],
#  'Sleep-disturbance-OR-Early-awakenings': [['sleep', 'disturbance'],
#   ['early', 'awakenings']],
#  '44-year': [['44', 'year']],
#  'FHx-of-PUD-OR-Family-history-of-peptic-ulcer-disease': [['fhx', 'of', 'pud'],
#   ['family', 'history', 'of', 'peptic', 'ulcer', 'disease']],
#  'Epigastric-discomfort': [['epigastric', 'discomfort']],
#  'Darker-bowel-movements': [['darker', 'bowel', 'movements']],
#  'NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use': [['nsaid', 'use'],
#   ['nonsteroidal', 'anti', 'inflammatory', 'drug', 'use']],
#  'burning-OR-gnawing-OR-burning-and-gnawing': [['burning'],
#   ['gnawing'],
#   ['burning', 'and', 'gnawing']],
#  'Post-prandial-bloating-OR-fullness-with-meals': [['post',
#    'prandial',
#    'bloating'],
#   ['fullness', 'with', 'meals']],
#  'getting-worse-OR-progressive-OR-symptoms-now-daily': [['getting', 'worse'],
#   ['progressive'],
#   ['symptoms', 'now', 'daily']],
#  '2-to-3-beers-a-week': [['2', 'to', '3', 'beers', 'a', 'week']],
#  'duration-2-months': [['duration', '2', 'months']],
#  'Awakens-at-night': [['awakens', 'at', 'night']],
#  'No-blood-in-stool': [['no', 'blood', 'in', 'stool']],
#  'Intermittent': [['intermittent']],
#  'Minimal-to-no-change-with-Tums': [['minimal',
#    'to',
#    'no',
#    'change',
#    'with',
#    'tums']],
#  'Nausea': [['nausea']],
#  '35-year': [['35', 'year']],
#  'Lack-of-other-thyroid-symptoms': [['lack',
#    'of',
#    'other',
#    'thyroid',
#    'symptoms']],
#  'anxious-OR-nervous': [['anxious'], ['nervous']],
#  'Stress-due-to-caring-for-elderly-parents': [['stress',
#    'due',
#    'to',
#    'caring',
#    'for',
#    'elderly',
#    'parents']],
#  'Heavy-caffeine-use': [['heavy', 'caffeine', 'use']],
#  'No-depressed-mood': [['no', 'depressed', 'mood']],
#  'Weight-stable': [['weight', 'stable']],
#  'Insomnia': [['insomnia']],
#  'Decreased-appetite': [['decreased', 'appetite']],
#  '45-year': [['45', 'year']],
#  'Onset-5-years-ago': [['onset', '5', 'years', 'ago']],
#  'No-caffeine-use': [['no', 'caffeine', 'use']],
#  'Associated-SOB-OR-Associated-shortness-of-breath': [['associated', 'sob'],
#   ['associated', 'shortness', 'of', 'breath']],
#  'Episodes-of-heart-racing': [['episodes', 'of', 'heart', 'racing']],
#  'Recent-visit-to-emergency-department-with-negative-workup': [['recent',
#    'visit',
#    'to',
#    'emergency',
#    'department',
#    'with',
#    'negative',
#    'workup']],
#  'No-chest-pain': [['no', 'chest', 'pain']],
#  'No-illicit-drug-use': [['no', 'illicit', 'drug', 'use']],
#  'Associated-nausea': [['associated', 'nausea']],
#  'Increased-frequency-recently': [['increased', 'frequency', 'recently']],
#  'Associated-feeling-of-impending-doom': [['associated',
#    'feeling',
#    'of',
#    'impending',
#    'doom']],
#  'Episodes-last-15-to-30-minutes': [['episodes',
#    'last',
#    '15',
#    'to',
#    '30',
#    'minutes']],
#  'Associated-throat-tightness': [['associated', 'throat', 'tightness']],
#  'Feels-hot-OR-Feels-clammy': [['feels', 'hot'], ['feels', 'clammy']],
#  'Episode-of-hand-numbness-OR-Episode-of-finger-numbness': [['episode',
#    'of',
#    'hand',
#    'numbness'],
#   ['episode', 'of', 'finger', 'numbness']],
#  'Fatigue-OR-Difficulty-concentrating': [['fatigue'],
#   ['difficulty', 'concentrating']],
#  'Increased-stress': [['increased', 'stress']],
#  '26-year': [['26', 'year']],
#  'Subjective-fevers': [['subjective', 'fevers']],
#  'Recent-upper-respiratory-symptoms': [['recent',
#    'upper',
#    'respiratory',
#    'symptoms']],
#  'Worse-with-deep-breath-OR-pleuritic': [['worse', 'with', 'deep', 'breath'],
#   ['pleuritic']],
#  'Exercise-induced-asthma': [['exercise', 'induced', 'asthma']],
#  'Chest-pain': [['chest', 'pain']],
#  'Duration-x-1-day': [['duration', 'x', '1', 'day']],
#  'No-shortness-of-breath': [['no', 'shortness', 'of', 'breath']],
#  'Recent-heavy-lifting-at-work-OR-recent-rock-climbing': [['recent',
#    'heavy',
#    'lifting',
#    'at',
#    'work'],
#   ['recent', 'rock', 'climbing']],
#  'No-relief-with-asthma-inhaler': [['no',
#    'relief',
#    'with',
#    'asthma',
#    'inhaler']],
#  'Sharp-OR-stabbing-OR-7-to-8-out-of-10-on-pain-scale': [['sharp'],
#   ['stabbing'],
#   ['7', 'to', '8', 'out', 'of', '10', 'on', 'pain', 'scale']],
#  'Weight-Gain': [['weight', 'gain']],
#  'heavy-periods-OR-irregular-periods': [['heavy', 'periods'],
#   ['irregular', 'periods']],
#  'Last-menstrual-period-2-months-ago': [['last',
#    'menstrual',
#    'period',
#    '2',
#    'months',
#    'ago']],
#  'Unprotected-Sex': [['unprotected', 'sex']],
#  'Fatigue': [['fatigue']],
#  'Infertility-HX-OR-Infertility-history': [['infertility', 'hx'],
#   ['infertility', 'history']],
#  'symptoms-for-6-months': [['symptoms', 'for', '6', 'months']],
#  'Increased-appetite': [['increased', 'appetite']],
#  'Son-died-3-weeks-ago': [['son', 'died', '3', 'weeks', 'ago']],
#  'Auditory-hallucination-once': [['auditory', 'hallucination', 'once']],
#  'tossing-and-turning': [['tossing', 'and', 'turning']],
#  '67-year': [['67', 'year']],
#  'Difficulty-falling-asleep': [['difficulty', 'falling', 'asleep']],
#  'Hallucinations-after-taking-Ambien': [['hallucinations',
#    'after',
#    'taking',
#    'ambien']],
#  'duration-3-weeks': [['duration', '3', 'weeks']],
#  'Unsuccessful-napping': [['unsuccessful', 'napping']],
#  'Sleeping-medication-ineffective': [['sleeping',
#    'medication',
#    'ineffective']],
#  'Diminished-energy-OR-feeling-drained': [['diminished', 'energy'],
#   ['feeling', 'drained']],
#  'loss-of-interest': [['loss', 'of', 'interest']],
#  'Visual-hallucination-once': [['visual', 'hallucination', 'once']],
#  'FHx-of-depression-OR-Family-history-of-depression': [['fhx',
#    'of',
#    'depression'],
#   ['family', 'history', 'of', 'depression']],
#  'Early-wakening': [['early', 'wakening']],
#  'No-suicidal-ideations': [['no', 'suicidal', 'ideations']],
#  'Difficulty-with-sleep': [['difficulty', 'with', 'sleep']],
#  'No-relief-with-Motrin-OR-no-relief-with-tylenol': [['no',
#    'relief',
#    'with',
#    'motrin'],
#   ['no', 'relief', 'with', 'tylenol']],
#  '1-day-duration-OR-2-days-duration': [['1', 'day', 'duration'],
#   ['2', 'days', 'duration']],
#  'Myalgias': [['myalgias']],
#  'Global-headache-OR-diffuse-headache': [['global', 'headache'],
#   ['diffuse', 'headache']],
#  'Neck-pain': [['neck', 'pain']],
#  'Vomiting': [['vomiting']],
#  'No-rash': [['no', 'rash']],
#  'viral-symptoms-OR-rhinorrhea-OR-scratchy-throat': [['viral', 'symptoms'],
#   ['rhinorrhea'],
#   ['scratchy', 'throat']],
#  'Shares-an-apartment': [['shares', 'an', 'apartment']],
#  'Meningococcal-vaccine-status-unknown': [['meningococcal',
#    'vaccine',
#    'status',
#    'unknown']],
#  'Family-history-of-migraines': [['family', 'history', 'of', 'migraines']],
#  'Photophobia': [['photophobia']],
#  'No-known-illness-contacts': [['no', 'known', 'illness', 'contacts']],
#  'Subjective-fever': [['subjective', 'fever']]}

# %%
from tqdm import tqdm
annotation_rate_dic = {}
threshold = 0.8
for feature_text in feature_text_list_unigram.keys():
    annotation_rate_dic[feature_text] = []
for feature_text, word_lists in feature_text_list_unigram.items():
    for word_list in word_lists:
        for word in word_list:
            annotation_count = sum(
                train[train["feature_text"] == feature_text]["annotation"].apply(
                    lambda x: word in " ".join(x).lower()
                )
            )
            pn_history_count = sum(
                train[train["feature_text"] == feature_text]["pn_history"].apply(
                    lambda x: word in x.lower()
                )
            )
            if pn_history_count != 0:
                annotation_rate = annotation_count / pn_history_count
                if annotation_rate > 0.8:
                    annotation_rate_dic[feature_text].append(
                        {
                            "word": word,
                            "annotation_rate": annotation_rate,
                            "pn_history_count": pn_history_count,
                        }
                    )
            else:
                print(f"{feature_text}, {word}: pn_history_count=0")
# Out:
# Right-sided-LQ-abdominal-pain-OR-Right-lower-quadrant-abdominal-pain, sided: pn_history_count=0
# Diminished-appetite, diminished: pn_history_count=0
# Recent-nausea-vomiting-OR-Recent-flulike-symptoms, flulike: pn_history_count=0
# Sleep-disturbance-OR-Early-awakenings, awakenings: pn_history_count=0
# NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use, nonsteroidal: pn_history_count=0
# NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use, anti: pn_history_count=0
# NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use, inflammatory: pn_history_count=0
# Post-prandial-bloating-OR-fullness-with-meals, prandial: pn_history_count=0
# Heavy-caffeine-use, heavy: pn_history_count=0
# Duration-x-1-day, duration: pn_history_count=0
# Unsuccessful-napping, unsuccessful: pn_history_count=0
# Unsuccessful-napping, napping: pn_history_count=0
# Sleeping-medication-ineffective, ineffective: pn_history_count=0
# viral-symptoms-OR-rhinorrhea-OR-scratchy-throat, viral: pn_history_count=0
# Shares-an-apartment, shares: pn_history_count=0
# Meningococcal-vaccine-status-unknown, status: pn_history_count=0
# Meningococcal-vaccine-status-unknown, unknown: pn_history_count=0

# %%
def match_annotation_rate(feature_text_list, threshold=0.8):
    annotation_rate_dic = {}
    for feature_text, word_lists in feature_text_list.items():
        annotation_rate_dic[feature_text] = []
        for word_list in word_lists:
            for word in word_list:
                annotation_count = sum(
                    train[train["feature_text"] == feature_text]["annotation"].apply(
                        lambda x: word in " ".join(x).lower()
                    )
                )
                pn_history_count = sum(
                    train[train["feature_text"] == feature_text]["pn_history"].apply(
                        lambda x: word in x.lower()
                    )
                )
                if pn_history_count != 0:
                    annotation_rate = annotation_count / pn_history_count
                    if annotation_rate > threshold:
                        annotation_rate_dic[feature_text].append(
                            {
                                "word": word,
                                "annotation_rate": annotation_rate,
                                "pn_history_count": pn_history_count,
                            }
                        )
#                 else:
#                     print(f"{feature_text}, {word}: pn_history_count=0")
    return annotation_rate_dic

# %%
unigram_annotation_rate_word_list = match_annotation_rate(feature_text_list_unigram, threshold=0.8)
bigram_annotation_rate_word_list = match_annotation_rate(feature_text_list_bigram, threshold=0.8)

# %%
bigram_annotation_rate_word_list
# Out:
# {'Family-history-of-MI-OR-Family-history-of-myocardial-infarction': [{'word': 'of mi',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'myocardial infarction',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'Family-history-of-thyroid-disorder': [{'word': 'thyroid disorder',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3}],
#  'Chest-pressure': [{'word': 'chest pressure',
#    'annotation_rate': 1.0,
#    'pn_history_count': 43}],
#  'Intermittent-symptoms': [],
#  'Lightheaded': [],
#  'No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance': [{'word': 'nail changes',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'no temperature', 'annotation_rate': 1.5, 'pn_history_count': 2},
#   {'word': 'temperature intolerance',
#    'annotation_rate': 1.0,
#    'pn_history_count': 4}],
#  'Adderall-use': [],
#  'Shortness-of-breath': [{'word': 'shortness of',
#    'annotation_rate': 0.8260869565217391,
#    'pn_history_count': 23},
#   {'word': 'of breath',
#    'annotation_rate': 0.8888888888888888,
#    'pn_history_count': 27}],
#  'Caffeine-use': [],
#  'heart-pounding-OR-heart-racing': [{'word': 'heart pounding',
#    'annotation_rate': 1.0425531914893618,
#    'pn_history_count': 47},
#   {'word': 'heart racing', 'annotation_rate': 1.5, 'pn_history_count': 8}],
#  'Few-months-duration': [],
#  '17-year': [{'word': '17 year',
#    'annotation_rate': 1.0,
#    'pn_history_count': 25}],
#  'Male': [],
#  'No-vaginal-discharge': [{'word': 'no vaginal',
#    'annotation_rate': 1.5,
#    'pn_history_count': 6},
#   {'word': 'vaginal discharge',
#    'annotation_rate': 1.0555555555555556,
#    'pn_history_count': 18}],
#  'Weight-loss': [{'word': 'weight loss',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 17}],
#  'Not-sexually-active': [{'word': 'not sexually',
#    'annotation_rate': 1.0,
#    'pn_history_count': 12},
#   {'word': 'sexually active',
#    'annotation_rate': 0.8070175438596491,
#    'pn_history_count': 57}],
#  'Prior-episodes-of-diarrhea': [],
#  '20-year': [{'word': '20 year',
#    'annotation_rate': 1.0,
#    'pn_history_count': 36}],
#  'No-bloody-bowel-movements': [],
#  'Recurrent-bouts-over-past-6-months': [{'word': 'over past',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3},
#   {'word': 'past 6',
#    'annotation_rate': 0.9545454545454546,
#    'pn_history_count': 22},
#   {'word': '6 months', 'annotation_rate': 1.0, 'pn_history_count': 33}],
#  'Right-sided-LQ-abdominal-pain-OR-Right-lower-quadrant-abdominal-pain': [{'word': 'lq abdominal',
#    'annotation_rate': 1.0,
#    'pn_history_count': 20},
#   {'word': 'right lower', 'annotation_rate': 1.0, 'pn_history_count': 28},
#   {'word': 'lower quadrant',
#    'annotation_rate': 0.9615384615384616,
#    'pn_history_count': 26},
#   {'word': 'quadrant abdominal',
#    'annotation_rate': 1.1428571428571428,
#    'pn_history_count': 7}],
#  'No-urinary-symptoms': [{'word': 'no urinary',
#    'annotation_rate': 4.0,
#    'pn_history_count': 2},
#   {'word': 'urinary symptoms', 'annotation_rate': 1.0, 'pn_history_count': 5}],
#  'Diminished-appetite': [],
#  'Normal-LMP-2-weeks-ago-OR-Normal-last-menstrual-period-2-weeks-ago': [{'word': 'lmp 2',
#    'annotation_rate': 1.0,
#    'pn_history_count': 43},
#   {'word': '2 weeks', 'annotation_rate': 1.0, 'pn_history_count': 69},
#   {'word': 'weeks ago',
#    'annotation_rate': 0.9705882352941176,
#    'pn_history_count': 68},
#   {'word': 'last menstrual', 'annotation_rate': 1.0, 'pn_history_count': 4},
#   {'word': 'period 2', 'annotation_rate': 1.0, 'pn_history_count': 4},
#   {'word': '2 weeks', 'annotation_rate': 1.0, 'pn_history_count': 69},
#   {'word': 'weeks ago',
#    'annotation_rate': 0.9705882352941176,
#    'pn_history_count': 68}],
#  '8-to-10-hours-of-acute-pain': [{'word': '10 hours',
#    'annotation_rate': 1.0,
#    'pn_history_count': 60}],
#  'Female': [],
#  'Prior-normal-periods': [{'word': 'normal periods',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'Last-Pap-smear-1-year-ago': [{'word': 'smear 1',
#    'annotation_rate': 1.25,
#    'pn_history_count': 4}],
#  'IUD': [],
#  'Sexually-active': [{'word': 'sexually active',
#    'annotation_rate': 1.0,
#    'pn_history_count': 52}],
#  'Vaginal-dryness': [{'word': 'vaginal dryness',
#    'annotation_rate': 0.9636363636363636,
#    'pn_history_count': 55}],
#  'Irregular-menses': [],
#  'Recent-nausea-vomiting-OR-Recent-flulike-symptoms': [],
#  'No-premenstrual-symptoms': [],
#  'Stress': [],
#  'LMP-2-months-ago-or-Last-menstrual-period-2-months-ago': [{'word': 'lmp 2',
#    'annotation_rate': 1.0,
#    'pn_history_count': 12},
#   {'word': '2 months', 'annotation_rate': 1.0, 'pn_history_count': 43},
#   {'word': 'months ago',
#    'annotation_rate': 0.9333333333333333,
#    'pn_history_count': 45},
#   {'word': 'last menstrual', 'annotation_rate': 0.875, 'pn_history_count': 8},
#   {'word': 'period 2', 'annotation_rate': 1.0, 'pn_history_count': 4},
#   {'word': '2 months', 'annotation_rate': 1.0, 'pn_history_count': 43},
#   {'word': 'months ago',
#    'annotation_rate': 0.9333333333333333,
#    'pn_history_count': 45}],
#  'Hot-flashes': [{'word': 'hot flashes',
#    'annotation_rate': 0.9726027397260274,
#    'pn_history_count': 73}],
#  'Irregular-flow-OR-Irregular-frequency-OR-Irregular-intervals': [{'word': 'irregular flow',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'Onset-3-years-ago': [{'word': '3 years',
#    'annotation_rate': 0.9264705882352942,
#    'pn_history_count': 68}],
#  'Heavy-sweating': [],
#  'Sleep-disturbance-OR-Early-awakenings': [],
#  '44-year': [],
#  'FHx-of-PUD-OR-Family-history-of-peptic-ulcer-disease': [{'word': 'of pud',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'peptic ulcer', 'annotation_rate': 1.0, 'pn_history_count': 12},
#   {'word': 'ulcer disease', 'annotation_rate': 1.0, 'pn_history_count': 8}],
#  'Epigastric-discomfort': [],
#  'Darker-bowel-movements': [],
#  'NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use': [{'word': 'nsaid use',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'burning-OR-gnawing-OR-burning-and-gnawing': [{'word': 'burning and',
#    'annotation_rate': 0.8571428571428571,
#    'pn_history_count': 7},
#   {'word': 'and gnawing', 'annotation_rate': 1.0, 'pn_history_count': 4}],
#  'Post-prandial-bloating-OR-fullness-with-meals': [{'word': 'fullness with',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'with meals',
#    'annotation_rate': 0.8333333333333334,
#    'pn_history_count': 6}],
#  'getting-worse-OR-progressive-OR-symptoms-now-daily': [{'word': 'getting worse',
#    'annotation_rate': 0.9166666666666666,
#    'pn_history_count': 12}],
#  '2-to-3-beers-a-week': [{'word': '3 beers',
#    'annotation_rate': 1.0,
#    'pn_history_count': 7},
#   {'word': 'beers a', 'annotation_rate': 1.0, 'pn_history_count': 15}],
#  'duration-2-months': [{'word': '2 months',
#    'annotation_rate': 0.9863013698630136,
#    'pn_history_count': 73}],
#  'Awakens-at-night': [{'word': 'awakens at',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'No-blood-in-stool': [{'word': 'no blood',
#    'annotation_rate': 0.8888888888888888,
#    'pn_history_count': 9},
#   {'word': 'blood in', 'annotation_rate': 1.0, 'pn_history_count': 10}],
#  'Intermittent': [],
#  'Minimal-to-no-change-with-Tums': [],
#  'Nausea': [],
#  '35-year': [{'word': '35 year',
#    'annotation_rate': 1.0,
#    'pn_history_count': 30}],
#  'Lack-of-other-thyroid-symptoms': [],
#  'anxious-OR-nervous': [],
#  'Stress-due-to-caring-for-elderly-parents': [{'word': 'to caring',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'caring for',
#    'annotation_rate': 0.8333333333333334,
#    'pn_history_count': 6},
#   {'word': 'for elderly', 'annotation_rate': 1.0, 'pn_history_count': 2},
#   {'word': 'elderly parents', 'annotation_rate': 1.0, 'pn_history_count': 1}],
#  'Heavy-caffeine-use': [{'word': 'caffeine use',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'No-depressed-mood': [{'word': 'depressed mood',
#    'annotation_rate': 1.0,
#    'pn_history_count': 4}],
#  'Weight-stable': [],
#  'Insomnia': [],
#  'Decreased-appetite': [{'word': 'decreased appetite',
#    'annotation_rate': 1.0,
#    'pn_history_count': 32}],
#  '45-year': [{'word': '45 year',
#    'annotation_rate': 1.0,
#    'pn_history_count': 21}],
#  'Onset-5-years-ago': [{'word': '5 years',
#    'annotation_rate': 1.0,
#    'pn_history_count': 64},
#   {'word': 'years ago', 'annotation_rate': 1.0, 'pn_history_count': 37}],
#  'No-caffeine-use': [{'word': 'caffeine use',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3}],
#  'Associated-SOB-OR-Associated-shortness-of-breath': [{'word': 'associated sob',
#    'annotation_rate': 4.0,
#    'pn_history_count': 2},
#   {'word': 'associated shortness',
#    'annotation_rate': 4.0,
#    'pn_history_count': 1},
#   {'word': 'shortness of', 'annotation_rate': 0.92, 'pn_history_count': 25},
#   {'word': 'of breath', 'annotation_rate': 0.9375, 'pn_history_count': 32}],
#  'Episodes-of-heart-racing': [{'word': 'heart racing',
#    'annotation_rate': 1.1428571428571428,
#    'pn_history_count': 7}],
#  'Recent-visit-to-emergency-department-with-negative-workup': [],
#  'No-chest-pain': [{'word': 'no chest',
#    'annotation_rate': 1.0769230769230769,
#    'pn_history_count': 13},
#   {'word': 'chest pain',
#    'annotation_rate': 0.9714285714285714,
#    'pn_history_count': 35}],
#  'No-illicit-drug-use': [{'word': 'no illicit',
#    'annotation_rate': 2.111111111111111,
#    'pn_history_count': 9},
#   {'word': 'illicit drug', 'annotation_rate': 1.0, 'pn_history_count': 23},
#   {'word': 'drug use',
#    'annotation_rate': 1.0357142857142858,
#    'pn_history_count': 28}],
#  'Associated-nausea': [{'word': 'associated nausea',
#    'annotation_rate': 7.0,
#    'pn_history_count': 2}],
#  'Increased-frequency-recently': [{'word': 'frequency recently',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'Associated-feeling-of-impending-doom': [{'word': 'of impending',
#    'annotation_rate': 1.0,
#    'pn_history_count': 8},
#   {'word': 'impending doom', 'annotation_rate': 1.0, 'pn_history_count': 11}],
#  'Episodes-last-15-to-30-minutes': [{'word': 'last 15',
#    'annotation_rate': 1.0,
#    'pn_history_count': 21},
#   {'word': '15 to', 'annotation_rate': 1.0, 'pn_history_count': 3},
#   {'word': 'to 30', 'annotation_rate': 1.0, 'pn_history_count': 3},
#   {'word': '30 minutes',
#    'annotation_rate': 0.9565217391304348,
#    'pn_history_count': 23}],
#  'Associated-throat-tightness': [{'word': 'throat tightness',
#    'annotation_rate': 0.9130434782608695,
#    'pn_history_count': 23}],
#  'Feels-hot-OR-Feels-clammy': [{'word': 'feels hot',
#    'annotation_rate': 1.3333333333333333,
#    'pn_history_count': 6},
#   {'word': 'feels clammy', 'annotation_rate': 1.0, 'pn_history_count': 3}],
#  'Episode-of-hand-numbness-OR-Episode-of-finger-numbness': [{'word': 'of hand',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2},
#   {'word': 'of finger', 'annotation_rate': 1.0, 'pn_history_count': 5},
#   {'word': 'finger numbness',
#    'annotation_rate': 1.1111111111111112,
#    'pn_history_count': 9}],
#  'Fatigue-OR-Difficulty-concentrating': [{'word': 'difficulty concentrating',
#    'annotation_rate': 1.0,
#    'pn_history_count': 6}],
#  'Increased-stress': [{'word': 'increased stress',
#    'annotation_rate': 1.0,
#    'pn_history_count': 5}],
#  '26-year': [],
#  'Subjective-fevers': [{'word': 'subjective fevers',
#    'annotation_rate': 1.0,
#    'pn_history_count': 5}],
#  'Recent-upper-respiratory-symptoms': [{'word': 'upper respiratory',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'Worse-with-deep-breath-OR-pleuritic': [{'word': 'worse with',
#    'annotation_rate': 0.8214285714285714,
#    'pn_history_count': 28},
#   {'word': 'with deep',
#    'annotation_rate': 1.0294117647058822,
#    'pn_history_count': 34},
#   {'word': 'deep breath', 'annotation_rate': 0.95, 'pn_history_count': 60}],
#  'Exercise-induced-asthma': [{'word': 'exercise induced',
#    'annotation_rate': 0.9629629629629629,
#    'pn_history_count': 54},
#   {'word': 'induced asthma',
#    'annotation_rate': 0.9882352941176471,
#    'pn_history_count': 85}],
#  'Chest-pain': [{'word': 'chest pain',
#    'annotation_rate': 0.9894736842105263,
#    'pn_history_count': 95}],
#  'Duration-x-1-day': [{'word': 'x 1',
#    'annotation_rate': 1.0,
#    'pn_history_count': 4},
#   {'word': '1 day', 'annotation_rate': 1.0, 'pn_history_count': 22}],
#  'No-shortness-of-breath': [{'word': 'no shortness',
#    'annotation_rate': 2.0,
#    'pn_history_count': 1},
#   {'word': 'shortness of', 'annotation_rate': 1.0, 'pn_history_count': 14},
#   {'word': 'of breath', 'annotation_rate': 1.0, 'pn_history_count': 14}],
#  'Recent-heavy-lifting-at-work-OR-recent-rock-climbing': [{'word': 'heavy lifting',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2},
#   {'word': 'lifting at', 'annotation_rate': 1.0, 'pn_history_count': 1},
#   {'word': 'rock climbing',
#    'annotation_rate': 0.8666666666666667,
#    'pn_history_count': 15}],
#  'No-relief-with-asthma-inhaler': [],
#  'Sharp-OR-stabbing-OR-7-to-8-out-of-10-on-pain-scale': [],
#  'Weight-Gain': [{'word': 'weight gain',
#    'annotation_rate': 1.0,
#    'pn_history_count': 41}],
#  'heavy-periods-OR-irregular-periods': [{'word': 'heavy periods',
#    'annotation_rate': 1.3333333333333333,
#    'pn_history_count': 21},
#   {'word': 'irregular periods',
#    'annotation_rate': 1.2272727272727273,
#    'pn_history_count': 22}],
#  'Last-menstrual-period-2-months-ago': [{'word': 'last menstrual',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3},
#   {'word': 'period 2', 'annotation_rate': 1.0, 'pn_history_count': 2},
#   {'word': '2 months',
#    'annotation_rate': 0.8947368421052632,
#    'pn_history_count': 38}],
#  'Unprotected-Sex': [],
#  'Fatigue': [],
#  'Infertility-HX-OR-Infertility-history': [],
#  'symptoms-for-6-months': [{'word': '6 months',
#    'annotation_rate': 0.85,
#    'pn_history_count': 80}],
#  'Increased-appetite': [{'word': 'increased appetite',
#    'annotation_rate': 1.0303030303030303,
#    'pn_history_count': 33}],
#  'Son-died-3-weeks-ago': [{'word': 'son died',
#    'annotation_rate': 1.0333333333333334,
#    'pn_history_count': 30},
#   {'word': 'died 3', 'annotation_rate': 1.2, 'pn_history_count': 5},
#   {'word': 'weeks ago',
#    'annotation_rate': 0.8490566037735849,
#    'pn_history_count': 53}],
#  'Auditory-hallucination-once': [{'word': 'auditory hallucination',
#    'annotation_rate': 1.0769230769230769,
#    'pn_history_count': 13}],
#  'tossing-and-turning': [{'word': 'tossing and',
#    'annotation_rate': 1.0,
#    'pn_history_count': 13},
#   {'word': 'and turning', 'annotation_rate': 1.0, 'pn_history_count': 12}],
#  '67-year': [{'word': '67 year',
#    'annotation_rate': 1.0,
#    'pn_history_count': 14}],
#  'Difficulty-falling-asleep': [{'word': 'difficulty falling',
#    'annotation_rate': 1.0263157894736843,
#    'pn_history_count': 38},
#   {'word': 'falling asleep',
#    'annotation_rate': 1.0754716981132075,
#    'pn_history_count': 53}],
#  'Hallucinations-after-taking-Ambien': [],
#  'duration-3-weeks': [{'word': '3 weeks',
#    'annotation_rate': 0.8354430379746836,
#    'pn_history_count': 79}],
#  'Unsuccessful-napping': [],
#  'Sleeping-medication-ineffective': [],
#  'Diminished-energy-OR-feeling-drained': [{'word': 'feeling drained',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'loss-of-interest': [{'word': 'of interest',
#    'annotation_rate': 0.9090909090909091,
#    'pn_history_count': 22}],
#  'Visual-hallucination-once': [{'word': 'visual hallucination',
#    'annotation_rate': 1.5,
#    'pn_history_count': 12}],
#  'FHx-of-depression-OR-Family-history-of-depression': [],
#  'Early-wakening': [],
#  'No-suicidal-ideations': [{'word': 'no suicidal',
#    'annotation_rate': 1.0,
#    'pn_history_count': 16},
#   {'word': 'suicidal ideations',
#    'annotation_rate': 1.0,
#    'pn_history_count': 4}],
#  'Difficulty-with-sleep': [],
#  'No-relief-with-Motrin-OR-no-relief-with-tylenol': [{'word': 'no relief',
#    'annotation_rate': 1.0,
#    'pn_history_count': 11},
#   {'word': 'relief with', 'annotation_rate': 1.0, 'pn_history_count': 4},
#   {'word': 'no relief', 'annotation_rate': 1.0, 'pn_history_count': 11},
#   {'word': 'relief with', 'annotation_rate': 1.0, 'pn_history_count': 4},
#   {'word': 'with tylenol',
#    'annotation_rate': 1.6666666666666667,
#    'pn_history_count': 3}],
#  '1-day-duration-OR-2-days-duration': [{'word': '1 day',
#    'annotation_rate': 0.8636363636363636,
#    'pn_history_count': 22},
#   {'word': 'days duration', 'annotation_rate': 1.0, 'pn_history_count': 1}],
#  'Myalgias': [],
#  'Global-headache-OR-diffuse-headache': [{'word': 'global headache',
#    'annotation_rate': 2.0,
#    'pn_history_count': 1}],
#  'Neck-pain': [{'word': 'neck pain',
#    'annotation_rate': 1.4,
#    'pn_history_count': 10}],
#  'Vomiting': [],
#  'No-rash': [{'word': 'no rash',
#    'annotation_rate': 1.3333333333333333,
#    'pn_history_count': 3}],
#  'viral-symptoms-OR-rhinorrhea-OR-scratchy-throat': [{'word': 'scratchy throat',
#    'annotation_rate': 1.0,
#    'pn_history_count': 12}],
#  'Shares-an-apartment': [{'word': 'an apartment',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3}],
#  'Meningococcal-vaccine-status-unknown': [],
#  'Family-history-of-migraines': [{'word': 'family history',
#    'annotation_rate': 0.875,
#    'pn_history_count': 8}],
#  'Photophobia': [],
#  'No-known-illness-contacts': [],
#  'Subjective-fever': [{'word': 'subjective fever',
#    'annotation_rate': 0.9523809523809523,
#    'pn_history_count': 21}]}

# %%
unigram_annotation_rate_word_list
# Out:
# {'Family-history-of-MI-OR-Family-history-of-myocardial-infarction': [{'word': 'myocardial',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'infarction', 'annotation_rate': 1.0, 'pn_history_count': 1}],
#  'Family-history-of-thyroid-disorder': [{'word': 'thyroid',
#    'annotation_rate': 1.0,
#    'pn_history_count': 87}],
#  'Chest-pressure': [{'word': 'pressure',
#    'annotation_rate': 0.9838709677419355,
#    'pn_history_count': 62}],
#  'Intermittent-symptoms': [{'word': 'intermittent',
#    'annotation_rate': 0.9444444444444444,
#    'pn_history_count': 18}],
#  'Lightheaded': [{'word': 'lightheaded',
#    'annotation_rate': 0.96,
#    'pn_history_count': 25}],
#  'No-hair-changes-OR-no-nail-changes-OR-no-temperature-intolerance': [{'word': 'nail',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'temperature', 'annotation_rate': 1.0, 'pn_history_count': 6},
#   {'word': 'intolerance', 'annotation_rate': 0.96, 'pn_history_count': 25}],
#  'Adderall-use': [{'word': 'adderall',
#    'annotation_rate': 1.0,
#    'pn_history_count': 46}],
#  'Shortness-of-breath': [{'word': 'shortness',
#    'annotation_rate': 0.8260869565217391,
#    'pn_history_count': 23},
#   {'word': 'breath',
#    'annotation_rate': 0.8666666666666667,
#    'pn_history_count': 30}],
#  'Caffeine-use': [],
#  'heart-pounding-OR-heart-racing': [{'word': 'heart',
#    'annotation_rate': 0.8620689655172413,
#    'pn_history_count': 87},
#   {'word': 'pounding',
#    'annotation_rate': 0.9830508474576272,
#    'pn_history_count': 59},
#   {'word': 'heart',
#    'annotation_rate': 0.8620689655172413,
#    'pn_history_count': 87},
#   {'word': 'racing',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 17}],
#  'Few-months-duration': [{'word': 'months',
#    'annotation_rate': 0.975609756097561,
#    'pn_history_count': 82}],
#  '17-year': [{'word': '17', 'annotation_rate': 1.0, 'pn_history_count': 195}],
#  'Male': [{'word': 'male',
#    'annotation_rate': 0.9534883720930233,
#    'pn_history_count': 129}],
#  'No-vaginal-discharge': [{'word': 'vaginal',
#    'annotation_rate': 0.8333333333333334,
#    'pn_history_count': 24},
#   {'word': 'discharge',
#    'annotation_rate': 0.9583333333333334,
#    'pn_history_count': 24}],
#  'Weight-loss': [{'word': 'weight',
#    'annotation_rate': 0.92,
#    'pn_history_count': 25}],
#  'Not-sexually-active': [{'word': 'sexually',
#    'annotation_rate': 0.8103448275862069,
#    'pn_history_count': 58}],
#  'Prior-episodes-of-diarrhea': [{'word': 'diarrhea',
#    'annotation_rate': 1.0,
#    'pn_history_count': 91}],
#  '20-year': [{'word': '20', 'annotation_rate': 1.0, 'pn_history_count': 196}],
#  'No-bloody-bowel-movements': [{'word': 'bloody',
#    'annotation_rate': 1.0,
#    'pn_history_count': 16}],
#  'Recurrent-bouts-over-past-6-months': [{'word': '6',
#    'annotation_rate': 0.9523809523809523,
#    'pn_history_count': 42}],
#  'Right-sided-LQ-abdominal-pain-OR-Right-lower-quadrant-abdominal-pain': [{'word': 'right',
#    'annotation_rate': 1.0,
#    'pn_history_count': 32},
#   {'word': 'lq',
#    'annotation_rate': 0.9672131147540983,
#    'pn_history_count': 61},
#   {'word': 'pain', 'annotation_rate': 0.88, 'pn_history_count': 100},
#   {'word': 'right', 'annotation_rate': 1.0, 'pn_history_count': 32},
#   {'word': 'lower',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 34},
#   {'word': 'quadrant',
#    'annotation_rate': 0.967741935483871,
#    'pn_history_count': 31},
#   {'word': 'pain', 'annotation_rate': 0.88, 'pn_history_count': 100}],
#  'No-urinary-symptoms': [{'word': 'urinary',
#    'annotation_rate': 1.0,
#    'pn_history_count': 25}],
#  'Diminished-appetite': [{'word': 'appetite',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 51}],
#  'Normal-LMP-2-weeks-ago-OR-Normal-last-menstrual-period-2-weeks-ago': [{'word': 'lmp',
#    'annotation_rate': 0.9848484848484849,
#    'pn_history_count': 66},
#   {'word': '2', 'annotation_rate': 0.83, 'pn_history_count': 100},
#   {'word': 'weeks', 'annotation_rate': 1.0, 'pn_history_count': 72},
#   {'word': '2', 'annotation_rate': 0.83, 'pn_history_count': 100},
#   {'word': 'weeks', 'annotation_rate': 1.0, 'pn_history_count': 72}],
#  '8-to-10-hours-of-acute-pain': [{'word': '8',
#    'annotation_rate': 0.9438202247191011,
#    'pn_history_count': 89},
#   {'word': '10',
#    'annotation_rate': 0.8979591836734694,
#    'pn_history_count': 98},
#   {'word': 'hours',
#    'annotation_rate': 0.9436619718309859,
#    'pn_history_count': 71}],
#  'Female': [{'word': 'female',
#    'annotation_rate': 0.9919678714859438,
#    'pn_history_count': 249}],
#  'Prior-normal-periods': [],
#  'Last-Pap-smear-1-year-ago': [],
#  'IUD': [{'word': 'iud',
#    'annotation_rate': 0.9782608695652174,
#    'pn_history_count': 46}],
#  'Sexually-active': [{'word': 'sexually',
#    'annotation_rate': 0.9818181818181818,
#    'pn_history_count': 55},
#   {'word': 'active', 'annotation_rate': 1.0, 'pn_history_count': 60}],
#  'Vaginal-dryness': [{'word': 'dryness',
#    'annotation_rate': 0.9649122807017544,
#    'pn_history_count': 57}],
#  'Irregular-menses': [{'word': 'irregular',
#    'annotation_rate': 1.0,
#    'pn_history_count': 96}],
#  'Recent-nausea-vomiting-OR-Recent-flulike-symptoms': [],
#  'No-premenstrual-symptoms': [],
#  'Stress': [],
#  'LMP-2-months-ago-or-Last-menstrual-period-2-months-ago': [{'word': 'lmp',
#    'annotation_rate': 0.9459459459459459,
#    'pn_history_count': 37}],
#  'Hot-flashes': [{'word': 'hot',
#    'annotation_rate': 0.9615384615384616,
#    'pn_history_count': 78},
#   {'word': 'flashes',
#    'annotation_rate': 0.9733333333333334,
#    'pn_history_count': 75}],
#  'Irregular-flow-OR-Irregular-frequency-OR-Irregular-intervals': [{'word': 'intervals',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'Onset-3-years-ago': [{'word': '3',
#    'annotation_rate': 0.8617021276595744,
#    'pn_history_count': 94},
#   {'word': 'years', 'annotation_rate': 0.8875, 'pn_history_count': 80}],
#  'Heavy-sweating': [{'word': 'sweating',
#    'annotation_rate': 0.9761904761904762,
#    'pn_history_count': 42}],
#  'Sleep-disturbance-OR-Early-awakenings': [],
#  '44-year': [{'word': '44', 'annotation_rate': 1.0, 'pn_history_count': 98}],
#  'FHx-of-PUD-OR-Family-history-of-peptic-ulcer-disease': [{'word': 'pud',
#    'annotation_rate': 1.0,
#    'pn_history_count': 11},
#   {'word': 'peptic', 'annotation_rate': 1.0, 'pn_history_count': 12},
#   {'word': 'ulcer', 'annotation_rate': 1.0, 'pn_history_count': 71},
#   {'word': 'disease', 'annotation_rate': 1.0, 'pn_history_count': 8}],
#  'Epigastric-discomfort': [{'word': 'epigastric',
#    'annotation_rate': 1.0,
#    'pn_history_count': 74}],
#  'Darker-bowel-movements': [{'word': 'darker',
#    'annotation_rate': 1.0,
#    'pn_history_count': 31}],
#  'NSAID-use-OR-Nonsteroidal-anti-inflammatory-drug-use': [{'word': 'nsaid',
#    'annotation_rate': 1.0,
#    'pn_history_count': 5}],
#  'burning-OR-gnawing-OR-burning-and-gnawing': [{'word': 'burning',
#    'annotation_rate': 0.9841269841269841,
#    'pn_history_count': 63},
#   {'word': 'gnawing',
#    'annotation_rate': 0.9655172413793104,
#    'pn_history_count': 29},
#   {'word': 'burning',
#    'annotation_rate': 0.9841269841269841,
#    'pn_history_count': 63},
#   {'word': 'gnawing',
#    'annotation_rate': 0.9655172413793104,
#    'pn_history_count': 29}],
#  'Post-prandial-bloating-OR-fullness-with-meals': [{'word': 'bloating',
#    'annotation_rate': 0.975,
#    'pn_history_count': 40},
#   {'word': 'fullness', 'annotation_rate': 1.0, 'pn_history_count': 5}],
#  'getting-worse-OR-progressive-OR-symptoms-now-daily': [{'word': 'progressive',
#    'annotation_rate': 1.0,
#    'pn_history_count': 15}],
#  '2-to-3-beers-a-week': [{'word': 'beers',
#    'annotation_rate': 0.9,
#    'pn_history_count': 40}],
#  'duration-2-months': [{'word': '2',
#    'annotation_rate': 0.8585858585858586,
#    'pn_history_count': 99},
#   {'word': 'months',
#    'annotation_rate': 0.9518072289156626,
#    'pn_history_count': 83}],
#  'Awakens-at-night': [{'word': 'awakens',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'No-blood-in-stool': [{'word': 'blood',
#    'annotation_rate': 0.9615384615384616,
#    'pn_history_count': 26}],
#  'Intermittent': [{'word': 'intermittent',
#    'annotation_rate': 0.9310344827586207,
#    'pn_history_count': 29}],
#  'Minimal-to-no-change-with-Tums': [{'word': 'minimal',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1},
#   {'word': 'tums',
#    'annotation_rate': 0.8421052631578947,
#    'pn_history_count': 76}],
#  'Nausea': [{'word': 'nausea',
#    'annotation_rate': 0.9708029197080292,
#    'pn_history_count': 137}],
#  '35-year': [{'word': '35', 'annotation_rate': 1.0, 'pn_history_count': 197}],
#  'Lack-of-other-thyroid-symptoms': [],
#  'anxious-OR-nervous': [{'word': 'anxious',
#    'annotation_rate': 0.8333333333333334,
#    'pn_history_count': 12},
#   {'word': 'nervous', 'annotation_rate': 1.0, 'pn_history_count': 94}],
#  'Stress-due-to-caring-for-elderly-parents': [{'word': 'caring',
#    'annotation_rate': 0.8333333333333334,
#    'pn_history_count': 6},
#   {'word': 'elderly', 'annotation_rate': 1.0, 'pn_history_count': 12}],
#  'Heavy-caffeine-use': [{'word': 'caffeine',
#    'annotation_rate': 0.9,
#    'pn_history_count': 10}],
#  'No-depressed-mood': [{'word': 'depressed',
#    'annotation_rate': 1.0,
#    'pn_history_count': 6},
#   {'word': 'mood', 'annotation_rate': 1.0, 'pn_history_count': 17}],
#  'Weight-stable': [{'word': 'weight',
#    'annotation_rate': 0.9607843137254902,
#    'pn_history_count': 51}],
#  'Insomnia': [{'word': 'insomnia',
#    'annotation_rate': 1.0,
#    'pn_history_count': 7}],
#  'Decreased-appetite': [{'word': 'appetite',
#    'annotation_rate': 0.9705882352941176,
#    'pn_history_count': 68}],
#  '45-year': [{'word': '45', 'annotation_rate': 1.0, 'pn_history_count': 99}],
#  'Onset-5-years-ago': [{'word': '5',
#    'annotation_rate': 0.9130434782608695,
#    'pn_history_count': 92},
#   {'word': 'years',
#    'annotation_rate': 0.9714285714285714,
#    'pn_history_count': 70}],
#  'No-caffeine-use': [{'word': 'caffeine',
#    'annotation_rate': 1.0,
#    'pn_history_count': 10}],
#  'Associated-SOB-OR-Associated-shortness-of-breath': [{'word': 'sob',
#    'annotation_rate': 0.9183673469387755,
#    'pn_history_count': 49},
#   {'word': 'shortness', 'annotation_rate': 0.92, 'pn_history_count': 25},
#   {'word': 'breath',
#    'annotation_rate': 0.9444444444444444,
#    'pn_history_count': 36}],
#  'Episodes-of-heart-racing': [{'word': 'racing',
#    'annotation_rate': 0.8888888888888888,
#    'pn_history_count': 18}],
#  'Recent-visit-to-emergency-department-with-negative-workup': [{'word': 'workup',
#    'annotation_rate': 0.9,
#    'pn_history_count': 10}],
#  'No-chest-pain': [],
#  'No-illicit-drug-use': [{'word': 'illicit',
#    'annotation_rate': 1.0,
#    'pn_history_count': 26},
#   {'word': 'drug',
#    'annotation_rate': 0.9753086419753086,
#    'pn_history_count': 81}],
#  'Associated-nausea': [{'word': 'nausea',
#    'annotation_rate': 0.8428571428571429,
#    'pn_history_count': 70}],
#  'Increased-frequency-recently': [{'word': 'frequency',
#    'annotation_rate': 0.8571428571428571,
#    'pn_history_count': 21}],
#  'Associated-feeling-of-impending-doom': [{'word': 'impending',
#    'annotation_rate': 1.0,
#    'pn_history_count': 12},
#   {'word': 'doom', 'annotation_rate': 1.0, 'pn_history_count': 16}],
#  'Episodes-last-15-to-30-minutes': [{'word': '15',
#    'annotation_rate': 0.9130434782608695,
#    'pn_history_count': 46},
#   {'word': '30', 'annotation_rate': 0.851063829787234, 'pn_history_count': 47},
#   {'word': 'minutes',
#    'annotation_rate': 0.9642857142857143,
#    'pn_history_count': 28}],
#  'Associated-throat-tightness': [{'word': 'throat',
#    'annotation_rate': 0.896551724137931,
#    'pn_history_count': 58}],
#  'Feels-hot-OR-Feels-clammy': [{'word': 'hot',
#    'annotation_rate': 0.8863636363636364,
#    'pn_history_count': 44},
#   {'word': 'clammy',
#    'annotation_rate': 0.9574468085106383,
#    'pn_history_count': 47}],
#  'Episode-of-hand-numbness-OR-Episode-of-finger-numbness': [{'word': 'numbness',
#    'annotation_rate': 0.8695652173913043,
#    'pn_history_count': 46},
#   {'word': 'finger',
#    'annotation_rate': 0.9423076923076923,
#    'pn_history_count': 52},
#   {'word': 'numbness',
#    'annotation_rate': 0.8695652173913043,
#    'pn_history_count': 46}],
#  'Fatigue-OR-Difficulty-concentrating': [{'word': 'fatigue',
#    'annotation_rate': 0.8888888888888888,
#    'pn_history_count': 9},
#   {'word': 'concentrating', 'annotation_rate': 1.0, 'pn_history_count': 7}],
#  'Increased-stress': [{'word': 'stress',
#    'annotation_rate': 0.9090909090909091,
#    'pn_history_count': 55}],
#  '26-year': [{'word': '26',
#    'annotation_rate': 0.9897959183673469,
#    'pn_history_count': 98}],
#  'Subjective-fevers': [{'word': 'subjective',
#    'annotation_rate': 1.0,
#    'pn_history_count': 21}],
#  'Recent-upper-respiratory-symptoms': [{'word': 'respiratory',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'Worse-with-deep-breath-OR-pleuritic': [{'word': 'deep',
#    'annotation_rate': 0.9342105263157895,
#    'pn_history_count': 76},
#   {'word': 'breath',
#    'annotation_rate': 0.8857142857142857,
#    'pn_history_count': 70},
#   {'word': 'pleuritic', 'annotation_rate': 1.0, 'pn_history_count': 5}],
#  'Exercise-induced-asthma': [{'word': 'exercise',
#    'annotation_rate': 0.9625,
#    'pn_history_count': 80},
#   {'word': 'induced',
#    'annotation_rate': 0.9772727272727273,
#    'pn_history_count': 88},
#   {'word': 'asthma',
#    'annotation_rate': 0.9494949494949495,
#    'pn_history_count': 99}],
#  'Chest-pain': [{'word': 'chest',
#    'annotation_rate': 0.979381443298969,
#    'pn_history_count': 97},
#   {'word': 'pain', 'annotation_rate': 0.96, 'pn_history_count': 100}],
#  'Duration-x-1-day': [{'word': 'day',
#    'annotation_rate': 0.9175257731958762,
#    'pn_history_count': 97}],
#  'No-shortness-of-breath': [{'word': 'shortness',
#    'annotation_rate': 1.0,
#    'pn_history_count': 14}],
#  'Recent-heavy-lifting-at-work-OR-recent-rock-climbing': [{'word': 'heavy',
#    'annotation_rate': 1.0,
#    'pn_history_count': 4},
#   {'word': 'lifting', 'annotation_rate': 1.0, 'pn_history_count': 5},
#   {'word': 'rock',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 34},
#   {'word': 'climbing', 'annotation_rate': 0.85, 'pn_history_count': 20}],
#  'No-relief-with-asthma-inhaler': [],
#  'Sharp-OR-stabbing-OR-7-to-8-out-of-10-on-pain-scale': [{'word': 'sharp',
#    'annotation_rate': 0.961038961038961,
#    'pn_history_count': 77},
#   {'word': 'stabbing', 'annotation_rate': 1.0, 'pn_history_count': 15}],
#  'Weight-Gain': [{'word': 'weight',
#    'annotation_rate': 0.9583333333333334,
#    'pn_history_count': 48},
#   {'word': 'gain', 'annotation_rate': 1.0, 'pn_history_count': 77}],
#  'heavy-periods-OR-irregular-periods': [{'word': 'heavy',
#    'annotation_rate': 0.971830985915493,
#    'pn_history_count': 71},
#   {'word': 'periods',
#    'annotation_rate': 0.8227848101265823,
#    'pn_history_count': 79},
#   {'word': 'irregular', 'annotation_rate': 0.9375, 'pn_history_count': 48},
#   {'word': 'periods',
#    'annotation_rate': 0.8227848101265823,
#    'pn_history_count': 79}],
#  'Last-menstrual-period-2-months-ago': [],
#  'Unprotected-Sex': [],
#  'Fatigue': [{'word': 'fatigue',
#    'annotation_rate': 0.8666666666666667,
#    'pn_history_count': 30}],
#  'Infertility-HX-OR-Infertility-history': [{'word': 'infertility',
#    'annotation_rate': 0.9473684210526315,
#    'pn_history_count': 19},
#   {'word': 'infertility',
#    'annotation_rate': 0.9473684210526315,
#    'pn_history_count': 19}],
#  'symptoms-for-6-months': [{'word': '6',
#    'annotation_rate': 0.9130434782608695,
#    'pn_history_count': 92},
#   {'word': 'months',
#    'annotation_rate': 0.8131868131868132,
#    'pn_history_count': 91}],
#  'Increased-appetite': [{'word': 'increased',
#    'annotation_rate': 0.96,
#    'pn_history_count': 50},
#   {'word': 'appetite',
#    'annotation_rate': 0.9074074074074074,
#    'pn_history_count': 54}],
#  'Son-died-3-weeks-ago': [{'word': 'son',
#    'annotation_rate': 0.979381443298969,
#    'pn_history_count': 97}],
#  'Auditory-hallucination-once': [{'word': 'auditory',
#    'annotation_rate': 0.9375,
#    'pn_history_count': 16}],
#  'tossing-and-turning': [{'word': 'tossing',
#    'annotation_rate': 1.0,
#    'pn_history_count': 15},
#   {'word': 'turning', 'annotation_rate': 1.0, 'pn_history_count': 14}],
#  '67-year': [{'word': '67', 'annotation_rate': 1.0, 'pn_history_count': 96}],
#  'Difficulty-falling-asleep': [{'word': 'falling',
#    'annotation_rate': 1.0,
#    'pn_history_count': 61},
#   {'word': 'asleep',
#    'annotation_rate': 0.9571428571428572,
#    'pn_history_count': 70}],
#  'Hallucinations-after-taking-Ambien': [],
#  'duration-3-weeks': [{'word': '3',
#    'annotation_rate': 0.8645833333333334,
#    'pn_history_count': 96},
#   {'word': 'weeks',
#    'annotation_rate': 0.8488372093023255,
#    'pn_history_count': 86}],
#  'Unsuccessful-napping': [],
#  'Sleeping-medication-ineffective': [],
#  'Diminished-energy-OR-feeling-drained': [{'word': 'energy',
#    'annotation_rate': 0.9782608695652174,
#    'pn_history_count': 46},
#   {'word': 'drained', 'annotation_rate': 1.0, 'pn_history_count': 10}],
#  'loss-of-interest': [{'word': 'interest',
#    'annotation_rate': 0.9508196721311475,
#    'pn_history_count': 61}],
#  'Visual-hallucination-once': [{'word': 'visual',
#    'annotation_rate': 0.9047619047619048,
#    'pn_history_count': 21}],
#  'FHx-of-depression-OR-Family-history-of-depression': [{'word': 'depression',
#    'annotation_rate': 0.9152542372881356,
#    'pn_history_count': 59},
#   {'word': 'depression',
#    'annotation_rate': 0.9152542372881356,
#    'pn_history_count': 59}],
#  'Early-wakening': [{'word': 'early',
#    'annotation_rate': 1.0,
#    'pn_history_count': 43}],
#  'No-suicidal-ideations': [{'word': 'suicidal',
#    'annotation_rate': 1.0,
#    'pn_history_count': 48},
#   {'word': 'ideations', 'annotation_rate': 1.0, 'pn_history_count': 4}],
#  'Difficulty-with-sleep': [{'word': 'sleep',
#    'annotation_rate': 0.9072164948453608,
#    'pn_history_count': 97}],
#  'No-relief-with-Motrin-OR-no-relief-with-tylenol': [{'word': 'relief',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 17},
#   {'word': 'motrin', 'annotation_rate': 1.0, 'pn_history_count': 1},
#   {'word': 'relief',
#    'annotation_rate': 0.9411764705882353,
#    'pn_history_count': 17},
#   {'word': 'tylenol',
#    'annotation_rate': 0.9454545454545454,
#    'pn_history_count': 55}],
#  '1-day-duration-OR-2-days-duration': [{'word': 'day',
#    'annotation_rate': 0.9175257731958762,
#    'pn_history_count': 97}],
#  'Myalgias': [{'word': 'myalgias',
#    'annotation_rate': 1.0,
#    'pn_history_count': 2}],
#  'Global-headache-OR-diffuse-headache': [{'word': 'global',
#    'annotation_rate': 1.0,
#    'pn_history_count': 3},
#   {'word': 'diffuse',
#    'annotation_rate': 0.8571428571428571,
#    'pn_history_count': 7}],
#  'Neck-pain': [{'word': 'neck',
#    'annotation_rate': 0.9210526315789473,
#    'pn_history_count': 38}],
#  'Vomiting': [{'word': 'vomiting',
#    'annotation_rate': 1.0,
#    'pn_history_count': 60}],
#  'No-rash': [{'word': 'rash', 'annotation_rate': 1.0, 'pn_history_count': 11}],
#  'viral-symptoms-OR-rhinorrhea-OR-scratchy-throat': [{'word': 'rhinorrhea',
#    'annotation_rate': 1.0,
#    'pn_history_count': 10},
#   {'word': 'scratchy', 'annotation_rate': 1.0, 'pn_history_count': 12},
#   {'word': 'throat',
#    'annotation_rate': 0.9285714285714286,
#    'pn_history_count': 28}],
#  'Shares-an-apartment': [{'word': 'apartment',
#    'annotation_rate': 1.0,
#    'pn_history_count': 6}],
#  'Meningococcal-vaccine-status-unknown': [{'word': 'meningococcal',
#    'annotation_rate': 1.0,
#    'pn_history_count': 1}],
#  'Family-history-of-migraines': [{'word': 'family',
#    'annotation_rate': 0.9375,
#    'pn_history_count': 16},
#   {'word': 'migraines',
#    'annotation_rate': 0.9583333333333334,
#    'pn_history_count': 48}],
#  'Photophobia': [{'word': 'photophobia',
#    'annotation_rate': 0.9565217391304348,
#    'pn_history_count': 46}],
#  'No-known-illness-contacts': [{'word': 'contacts',
#    'annotation_rate': 0.9714285714285714,
#    'pn_history_count': 35}],
#  'Subjective-fever': [{'word': 'subjective',
#    'annotation_rate': 0.9545454545454546,
#    'pn_history_count': 22}]}

# %%
train[train["feature_text"]=="8-to-10-hours-of-acute-pain"]["annotation"]
# Out:
# 1311                                 [last 10 hours]
# 1324                              [onset 8-10 hours]
# 1337                    [pain for the past 10 hours]
# 1350                       [began about 8 hours ago]
# 1363                        [started 8-10 hours ago]
# 1376                    [8-10 HOURS SUDDEN IN ONSET]
# 1389                           [pain for 8-10 hours]
# 1402                                    [for 10 ago]
# 1415                                [8-10 hours ago]
# 1428                                              []
# 1441                          [started 8-10 hr back]
# 1454                                              []
# 1467                       [For the last 8-10 hours]
# 1480                                   [pain 10 hrs]
# 1493                             [8-10 hour history]
# 1506                        [started 8-10 hours ago]
# 1519                      [Pain began ~8-10 hrs ago]
# 1532                             [pain for 8-10 hrs]
# 1545                           [started 8-10hrs ago]
# 1558                                              []
# 1571                 [abdominal pain began 8-10 hrs]
# 1584                     [Pain began 8-10 hours ago]
# 1597                           [PAIN - 10 hrs acute]
# 1610                          [began 8-10 hours ago]
# 1623                                              []
# 1636                                              []
# 1649                   [pain started 8-10 hours ago]
# 1662                                 [past 8-10 hrs]
# 1675                                [8-10 hours ago]
# 1688                               [past 8-10 hours]
# 1701                        [started 8-10 hours ago]
# 1714                  [started about 8-10 hours ago]
# 1727                     [pain began 8-10 hours ago]
# 1740                  [pain for the past 8-10 hours]
# 1753                  [PAIN X 8-10 HRS SUDDEN ONSET]
# 1766              [pain that started 8-10 hours ago]
# 1779                   [pain started 8-10 hours ago]
# 1792                     [8-10 hour history of pain]
# 1805                 [came on suddenly 10 hours ago]
# 1818                                 [last 8-10 hrs]
# 1831                               [last 8-10 hours]
# 1844                                 [with 10 hours]
# 1857                                    [8-10 H AGO]
# 1870                          [start 8-10 hours ago]
# 1883                       [for the past 8-10 hours]
# 1896                        [started 8-10 hours ago]
# 1909                                         [8-10h]
# 1922                          [onset 8-10 hours ago]
# 1935                   [pain started 8-10 hours ago]
# 1948                                    [8-10 hours]
# 1961                 [STARTED SUDDENLY 10 HOURS AGO]
# 1974                      [since 8-10hrs ago sudden]
# 1987                           [started 8-10hrs ago]
# 2000                        [Started 8-10 hours ago]
# 2013                        [Started 8-10 hours ago]
# 2026                                      [8-10 HRS]
# 2039                     [pain began 8-10 hours ago]
# 2052                           [8-10 hours duration]
# 2065                             [awoken from sleep]
# 2078                    [pain for the last 10 hours]
# 2091                   [pain started 8-10 hours ago]
# 2104                      [pain started 8-10 hr ago]
# 2117                      [8 hours started suddenly]
# 2130                                [for 8-10 hours]
# 2143                             [8-10 hour of pain]
# 2156                       [pain Started 8-10 hours]
# 2169                                  [for 8-10 hrs]
# 2182                  [suddenly started 8 hours ago]
# 2195                        [started 8-10 hours ago]
# 2208              [pain that started 8-10 hours ago]
# 2221                               [8 hours of pain]
# 2234                 [pain awoke her 8-10 hours ago]
# 2247    [pain started suddenly about 8-10 hours ago]
# 2260                           [onset: 8-10 hrs ago]
# 2273                       [started 8-10 hours a go]
# 2286                         [started 8-10 days ago]
# 2299                          [pain last 8-10 hours]
# 2312                  [started about 8-10 hours ago]
# 2325                          [since 8-10 Hours ago]
# 2338      [abdominal pain that began 8-10 hours ago]
# 2351                               [past 8-10 hours]
# 2364                            [STARTED 8-10 HOURS]
# 2377                        [started 8-10 hours ago]
# 2390                      [pain of 8 hours duration]
# 2403                          [Started 8-10 hrs ago]
# 2416             [8-10 hours, for the last 10 hours]
# 2429                         [STARTED 8-10HOURS AGO]
# 2442                [pain that began 8-10 hours ago]
# 2455                  [pain for the past 8-10 hours]
# 2468                   [for 8 hours pain was sudden]
# 2481                           [started 8-10hrs ago]
# 2494                                [8-10 hours ago]
# 2507              [PAIN IS ACUTE STARTED 8-10 H AGO]
# 2520                        [started 8-10 hours ago]
# 2533                  [pain Onset of 8-10 hours ago]
# 2546                               [past 8-10 hours]
# 2559                  [pain, started 8-10 hours ago]
# 2572               [8-10 HOURS AGO STARTED SUDDENLY]
# 2585                        [started 8-10 hours ago]
# 2598                                        [10 hrs]
# Name: annotation, dtype: object

# %%
test["feature_text"].uniqueque()
# Out:
# 5
