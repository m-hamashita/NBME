# %% [markdown]
# ### データの雰囲気を掴む

# %%
import os
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("display.width", 1000)

# %%
INPUT_DIR = Path('../input')
OUTPUT_DIR = Path('../output/000_exp')
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
train = pd.read_csv(INPUT_DIR / "train.csv")
feature = pd.read_csv(INPUT_DIR / "features.csv")
patient_notes = pd.read_csv(INPUT_DIR / "patient_notes.csv")

# %%
display(train.head(30))
display(feature.head(30))
display(patient_notes.head(30))
# Out:
#            id  case_num  pn_num  feature_num                                  annotation                           location
# 0   00016_000         0      16            0            ['dad with recent heart attcak']                        ['696 724']
# 1   00016_001         0      16            1               ['mom with "thyroid disease']                        ['668 693']
# 2   00016_002         0      16            2                          ['chest pressure']                        ['203 217']
# 3   00016_003         0      16            3        ['intermittent episodes', 'episode']               ['70 91', '176 183']
# 4   00016_004         0      16            4    ['felt as if he were going to pass out']                        ['222 258']
# 5   00016_005         0      16            5                                          []                                 []
# 6   00016_006         0      16            6      ['adderall', 'adderrall', 'adderrall']  ['321 329', '404 413', '652 661']
# 7   00016_007         0      16            7                                          []                                 []
# 8   00016_008         0      16            8                                          []                                 []
# 9   00016_009         0      16            9  ['palpitations', 'heart beating/pounding']                ['26 38', '96 118']
# 10  00016_010         0      16           10                           ['3-4 months of']                          ['56 69']
# 11  00016_011         0      16           11                                    ['17yo']                            ['5 9']
# 12  00016_012         0      16           12                                       ['M']                          ['10 11']
# 13  00041_000         0      41            0                                          []                                 []
# 14  00041_001         0      41            1                ['MOM HAS THYROID PROBLEMS']                        ['532 556']
# 15  00041_002         0      41            2                   ['PRESSURE ON HER CHEST']                        ['263 284']
# 16  00041_003         0      41            3    ['COMES AND GOES', 'HAPPENED 5-6 TIMES']             ['131 145', '150 168']
# 17  00041_004         0      41            4                                          []                                 []
# 18  00041_005         0      41            5                                          []                                 []
# 19  00041_006         0      41            6                                          []                                 []
# 20  00041_007         0      41            7                                     ['SOB']                        ['258 261']
# 21  00041_008         0      41            8                                          []                                 []
# 22  00041_009         0      41            9                          ['HEART POUNDING']                          ['32 46']
# 23  00041_010         0      41           10                      ['STARTED 2-3 MO AGO']                          ['48 66']
# 24  00041_011         0      41           11                                  ['17 Y/O']                            ['0 6']
# 25  00041_012         0      41           12                                       ['M']                            ['7 8']
# 26  00046_000         0      46            0                    ['father: heart attack']                        ['824 844']
# 27  00046_001         0      46            1                     ['mom: thyroid issues']                        ['803 822']
# 28  00046_002         0      46            2                                          []                                 []
# 29  00046_003         0      46            3                            ['sporadically']                        ['184 196']
#     feature_num  case_num                                       feature_text
# 0             0         0  Family-history-of-MI-OR-Family-history-of-myoc...
# 1             1         0                 Family-history-of-thyroid-disorder
# 2             2         0                                     Chest-pressure
# 3             3         0                              Intermittent-symptoms
# 4             4         0                                        Lightheaded
# 5             5         0  No-hair-changes-OR-no-nail-changes-OR-no-tempe...
# 6             6         0                                       Adderall-use
# 7             7         0                                Shortness-of-breath
# 8             8         0                                       Caffeine-use
# 9             9         0                     heart-pounding-OR-heart-racing
# 10           10         0                                Few-months-duration
# 11           11         0                                            17-year
# 12           12         0                                               Male
# 13          100         1                               No-vaginal-discharge
# 14          101         1                                        Weight-loss
# 15          102         1                                Not-sexually-active
# 16          103         1                         Prior-episodes-of-diarrhea
# 17          104         1                                            20-year
# 18          105         1                          No-bloody-bowel-movements
# 19          106         1                 Recurrent-bouts-over-past-6-months
# 20          107         1  Right-sided-LQ-abdominal-pain-OR-Right-lower-q...
# 21          108         1                                No-urinary-symptoms
# 22          109         1                                Diminished-appetite
# 23          110         1  Normal-LMP-2-weeks-ago-OR-Normal-last-menstrua...
# 24          111         1                        8-to-10-hours-of-acute-pain
# 25          112         1                                             Female
# 26          200         2                               Prior-normal-periods
# 27          201         2                          Last-Pap-smear-I-year-ago
# 28          202         2                                                IUD
# 29          203         2                                    Sexually-active
#     pn_num  case_num                                         pn_history
# 0        0         0  17-year-old male, has come to the student heal...
# 1        1         0  17 yo male with recurrent palpitations for the...
# 2        2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3        3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4        4         0  17yo male with no pmh here for evaluation of p...
# 5        5         0  17 yo m, presenting with palpitations/increase...
# 6        6         0  17 yo male presents with 3-4 month history of ...
# 7        7         0  17 yo male presents with a 2-3 month history o...
# 8        8         0  HPI: 17 YO complains of intermittent heart pal...
# 9        9         0  Mr. Cleveland is a 17 yo M who presents to cli...
# 10      10         0  Mr. Cleveland is a 17 year old male with no si...
# 11      11         0  Dillon Cleveland is a 17 year old male with no...
# 12      12         0  Patient is a 17 yo male presenting to student ...
# 13      13         0  17 yr old boy complaining of heart pounding fo...
# 14      14         0  17 year old male with no significant PMH. Comp...
# 15      15         0  Mr. Cleveland is a 17 yo male who presents tod...
# 16      16         0  HPI: 17yo M presents with palpitations. Patien...
# 17      17         0  17 yo male presents with 2-3 months of "poundi...
# 18      18         0  HPI Mr. Cleveland is a 17yo male presenting fo...
# 19      19         0  17yo M presents with heart palpitations. He ha...
# 20      20         0  17 yo M presents with 3-4 months of intermitte...
# 21      21         0  17yo M presents with CC of episodes of heart p...
# 22      22         0  17-year-old male, has come to the student heal...
# 23      23         0  Mr. Cleveland is a 17yo male presenting with 2...
# 24      24         0  17 yo M presents with heart punding for 3-4 mo...
# 25      25         0  17-year-old male presents with palpitations. H...
# 26      26         0  Mr Cleveland is 17 y o male presenting with pa...
# 27      27         0  Patient is a 17 year old male who presents wit...
# 28      28         0  Dillon Cleveland is a 17 y/o M with a CC that ...
# 29      29         0  17 Y/O M in clinic due to recurrent heart poun...
